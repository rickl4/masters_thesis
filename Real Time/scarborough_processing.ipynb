# %%
import pandas as pd
import numpy as np

import os

# %%
df_list = []
departures = []

for file in os.listdir('cleaned_scarborough'):
    
    if file[0] == '.':
        continue
    
    period = file.split('_')[3].split('.')[0]
    date = file.split('_')[2].split('.')[0]

    raw = pd.read_csv('cleaned_scarborough/' + file)

    raw['platform1_end_time'] = pd.DatetimeIndex(raw['platform1_end_time'], tz = 'America/Toronto')
    raw['platform2_start_time'] = pd.DatetimeIndex(raw['platform2_start_time'], tz = 'America/Toronto')
    raw = raw.sort_values(by = 'platform2_start_time')
    if (period == 'EV') | (period == 'PM') :

        test_left = raw[(raw['station2'] == 'lawrence_east') & (raw['station1'] == 'kennedy')].copy()
        station1 = 'kennedy'
        station2 = 'lawrence_east'
    else:
        test_left = raw[(raw['station1'] == 'lawrence_east') & (raw['station2'] == 'kennedy')].copy()
        station2 = 'kennedy'
        station1 = 'lawrence_east'
    test_left = test_left.reset_index(drop = True).reset_index()
    test_right = test_left.copy()
    test_right['index'] = test_right['index'] - 1


    test = test_left.merge(test_right[['index', 'platform1_end_time', 'platform2_start_time']], left_on = ['index'], right_on = ['index'], suffixes = ['_left', '_right'])

    test['gap'] = (test['platform2_start_time_right'] - test['platform2_start_time_left']).dt.seconds

    test['train_id'] = (test['gap'] > 90).cumsum() # minimum gap needed to indicate a new train is approaching

    train_times = []

    for train_id in list(test['train_id'].drop_duplicates()):
        station1 = station1
        station2 = station2
        depart_time = test[test['train_id'] == train_id]['platform1_end_time_left'].median()
        arrival_time = test[test['train_id'] == train_id]['platform2_start_time_left'].median()

        train_times.append([station1, station2, depart_time, arrival_time])

    df_list.append(test[test['gap']> 450])
    departures.append(pd.DataFrame.from_records(train_times, columns = ['station1', 'station2', 'depart_time', 'arrival_time']))

# %%
gaps = pd.concat(df_list)
departures_df = pd.concat(departures)

# %%
gaps.to_csv('processed_scarborough/gaps.csv', index = False)
departures_df.to_csv('processed_scarborough/srt_departures.csv', index = False)

# %%
gaps.sort_values(by = 'gap', ascending = False).head(50)
# Out:
#      index       station1       station2          platform1_end_time_left  \
# 57      57  lawrence_east        kennedy 2019-11-27 10:36:12.536000-05:00
# 48      48        kennedy  lawrence_east 2019-12-06 20:59:17.589000-05:00
# 98      98        kennedy  lawrence_east 2019-12-02 23:07:21.696000-05:00
# 112    112        kennedy  lawrence_east 2019-12-11 00:29:11.271000-05:00
# 24      24        kennedy  lawrence_east 2019-12-27 20:54:16.953000-05:00
# 114    114        kennedy  lawrence_east 2019-12-17 00:30:11.335000-05:00
# 111    111        kennedy  lawrence_east 2019-12-05 23:50:11.107000-05:00
# 6        6        kennedy  lawrence_east 2019-12-17 20:22:53.783000-05:00
# 212    212        kennedy  lawrence_east 2019-12-17 20:22:53.783000-05:00
# 33      33        kennedy  lawrence_east 2019-12-04 21:22:29.201000-05:00
# 39      39        kennedy  lawrence_east 2019-12-03 21:49:26.353000-05:00
# 88      88        kennedy  lawrence_east 2020-01-04 00:03:05.241000-05:00
# 105    105        kennedy  lawrence_east 2019-12-20 00:07:14.201000-05:00
# 96      96        kennedy  lawrence_east 2019-12-12 00:04:44.598000-05:00
# 76      76        kennedy  lawrence_east 2019-12-11 22:55:46.733000-05:00
# 173    173        kennedy  lawrence_east 2019-12-18 19:25:12.635000-05:00
# 126    126        kennedy  lawrence_east 2019-11-28 00:24:33.381000-05:00
# 99      99        kennedy  lawrence_east 2019-12-06 23:47:25.254000-05:00
# 42      42        kennedy  lawrence_east 2019-11-28 21:15:01.043000-05:00
# 4        4        kennedy  lawrence_east 2019-12-10 20:06:25.647000-05:00
# 199    199        kennedy  lawrence_east 2019-12-10 20:06:25.647000-05:00
# 36      36        kennedy  lawrence_east 2019-12-03 21:32:17.243000-05:00
# 100    100        kennedy  lawrence_east 2019-12-12 00:27:41.851000-05:00
# 85      85        kennedy  lawrence_east 2019-12-19 23:14:42.766000-05:00
# 99      99        kennedy  lawrence_east 2019-12-10 00:17:08.923000-05:00
# 15      15        kennedy  lawrence_east 2019-12-03 20:33:18.502000-05:00
# 243    243        kennedy  lawrence_east 2019-12-03 20:33:18.502000-05:00
# 72      72        kennedy  lawrence_east 2019-11-27 22:07:16.387000-05:00
# 160    160  lawrence_east        kennedy 2019-12-12 15:05:54.312000-05:00
# 56      56        kennedy  lawrence_east 2019-12-13 22:09:08.554000-05:00
# 168    168        kennedy  lawrence_east 2020-01-02 20:04:51.474000-05:00
# 1        1        kennedy  lawrence_east 2020-01-02 20:04:51.474000-05:00
# 120    120        kennedy  lawrence_east 2019-12-30 18:50:10.740000-05:00
# 80      80        kennedy  lawrence_east 2020-01-03 00:09:59.709000-05:00
# 198    198        kennedy  lawrence_east 2019-12-16 20:05:08.162000-05:00
# 3        3        kennedy  lawrence_east 2019-12-16 20:05:08.162000-05:00
# 45      45        kennedy  lawrence_east 2019-12-23 22:00:51.557000-05:00
# 117    117        kennedy  lawrence_east 2019-12-03 00:09:32.092000-05:00
# 114    114        kennedy  lawrence_east 2019-11-27 23:32:57.791000-05:00
# 54      54        kennedy  lawrence_east 2019-12-18 21:24:24.026000-05:00
# 102    102        kennedy  lawrence_east 2019-12-07 00:06:58.338000-05:00
# 132    132  lawrence_east        kennedy 2019-12-16 14:40:06.192000-05:00
# 124    124        kennedy  lawrence_east 2019-11-28 00:04:29.162000-05:00
# 48      48  lawrence_east        kennedy 2019-12-16 12:39:20.712000-05:00
# 83      83        kennedy  lawrence_east 2019-12-03 23:59:25.461000-05:00
# 80      80        kennedy  lawrence_east 2019-12-04 23:24:08.510000-05:00
# 103    103        kennedy  lawrence_east 2019-12-21 00:13:55.763000-05:00
# 97      97        kennedy  lawrence_east 2019-11-29 23:51:49.265000-05:00
# 94      94        kennedy  lawrence_east 2019-12-24 00:02:25.935000-05:00
# 100    100        kennedy  lawrence_east 2019-11-30 00:04:39.827000-05:00
#
#            platform2_start_time_left  year month day hour        date dow  \
# 57  2019-11-27 10:41:48.892000-05:00  2019    11  27   10  2019-11-27   2
# 48  2019-12-06 21:11:52.463000-05:00  2019    12   7   20  2019-12-06   4
# 98  2019-12-02 23:14:30.547000-05:00  2019    12   3   23  2019-12-02   0
# 112 2019-12-11 00:35:14.731000-05:00  2019    12  11    0  2019-12-10   1
# 24  2019-12-27 21:04:55.082000-05:00  2019    12  28   20  2019-12-27   4
# 114 2019-12-17 00:41:35.323000-05:00  2019    12  17    0  2019-12-16   0
# 111 2019-12-05 23:56:50.684000-05:00  2019    12   6   23  2019-12-05   3
# 6   2019-12-17 20:27:56.350000-05:00  2019    12  18   20  2019-12-17   1
# 212 2019-12-17 20:27:56.350000-05:00  2019    12  18   20  2019-12-17   1
# 33  2019-12-04 21:27:57.881000-05:00  2019    12   5   21  2019-12-04   2
# 39  2019-12-03 22:02:06.332000-05:00  2019    12   4   21  2019-12-03   1
# 88  2020-01-04 00:09:55.084000-05:00  2020     1   4    0  2020-01-03   4
# 105 2019-12-20 00:17:49.246000-05:00  2019    12  20    0  2019-12-19   3
# 96  2019-12-12 00:10:59.003000-05:00  2019    12  12    0  2019-12-11   2
# 76  2019-12-11 23:03:58.424000-05:00  2019    12  12   22  2019-12-11   2
# 173 2019-12-18 19:32:22.506000-05:00  2019    12  19   19  2019-12-18   2
# 126 2019-11-28 00:32:07.859000-05:00  2019    11  28    0  2019-11-27   2
# 99  2019-12-06 23:58:03.762000-05:00  2019    12   7   23  2019-12-06   4
# 42  2019-11-28 21:27:25.251000-05:00  2019    11  29   21  2019-11-28   3
# 4   2019-12-10 20:15:39.112000-05:00  2019    12  11   20  2019-12-10   1
# 199 2019-12-10 20:15:39.112000-05:00  2019    12  11   20  2019-12-10   1
# 36  2019-12-03 21:44:06.923000-05:00  2019    12   4   21  2019-12-03   1
# 100 2019-12-12 00:41:01.835000-05:00  2019    12  12    0  2019-12-11   2
# 85  2019-12-19 23:23:16.191000-05:00  2019    12  20   23  2019-12-19   3
# 99  2019-12-10 00:27:07.425000-05:00  2019    12  10    0  2019-12-09   0
# 15  2019-12-03 20:39:03.577000-05:00  2019    12   4   20  2019-12-03   1
# 243 2019-12-03 20:39:03.577000-05:00  2019    12   4   20  2019-12-03   1
# 72  2019-11-27 22:21:29.494000-05:00  2019    11  28   22  2019-11-27   2
# 160 2019-12-12 15:10:46.937000-05:00  2019    12  12   15  2019-12-12   3
# 56  2019-12-13 22:14:23.407000-05:00  2019    12  14   22  2019-12-13   4
# 168 2020-01-02 20:11:44.367000-05:00  2020     1   3   20  2020-01-02   3
# 1   2020-01-02 20:11:44.367000-05:00  2020     1   3   20  2020-01-02   3
# 120 2019-12-30 19:04:59.662000-05:00  2019    12  30   18  2019-12-30   0
# 80  2020-01-03 00:15:17.463000-05:00  2020     1   3    0  2020-01-02   3
# 198 2019-12-16 20:14:22.891000-05:00  2019    12  17   20  2019-12-16   0
# 3   2019-12-16 20:14:22.891000-05:00  2019    12  17   20  2019-12-16   0
# 45  2019-12-23 22:11:15.032000-05:00  2019    12  24   22  2019-12-23   0
# 117 2019-12-03 00:17:13.051000-05:00  2019    12   3    0  2019-12-02   0
# 114 2019-11-27 23:43:38.930000-05:00  2019    11  28   23  2019-11-27   2
# 54  2019-12-18 21:34:52.056000-05:00  2019    12  19   21  2019-12-18   2
# 102 2019-12-07 00:20:03.911000-05:00  2019    12   7    0  2019-12-06   4
# 132 2019-12-16 14:44:10.564000-05:00  2019    12  16   14  2019-12-16   0
# 124 2019-11-28 00:09:58.337000-05:00  2019    11  28    0  2019-11-27   2
# 48  2019-12-16 12:45:50.161000-05:00  2019    12  16   12  2019-12-16   0
# 83  2019-12-04 00:03:19.802000-05:00  2019    12   4   23  2019-12-03   1
# 80  2019-12-04 23:34:46.988000-05:00  2019    12   5   23  2019-12-04   2
# 103 2019-12-21 00:23:45.329000-05:00  2019    12  21    0  2019-12-20   4
# 97  2019-11-29 23:56:48.016000-05:00  2019    11  30   23  2019-11-29   4
# 94  2019-12-24 00:12:41.514000-05:00  2019    12  24    0  2019-12-23   0
# 100 2019-11-30 00:11:34.111000-05:00  2019    11  30    0  2019-11-29   4
#
#     period         platform1_end_time_right       platform2_start_time_right  \
# 57      AM 2019-11-27 11:09:34.343000-05:00 2019-11-27 11:15:46.243000-05:00
# 48      EV 2019-12-06 21:25:43.355000-05:00 2019-12-06 21:35:03.076000-05:00
# 98      EV 2019-12-02 23:25:59.899000-05:00 2019-12-02 23:37:12.939000-05:00
# 112     EV 2019-12-11 00:49:16.951000-05:00 2019-12-11 00:57:30.392000-05:00
# 24      EV 2019-12-27 21:19:37.821000-05:00 2019-12-27 21:26:12.607000-05:00
# 114     EV 2019-12-17 00:56:18.979000-05:00 2019-12-17 01:02:51.334000-05:00
# 111     EV 2019-12-06 00:10:18.051000-05:00 2019-12-06 00:17:26.712000-05:00
# 6       EV 2019-12-17 20:41:44.895000-05:00 2019-12-17 20:48:21.897000-05:00
# 212     PM 2019-12-17 20:41:44.895000-05:00 2019-12-17 20:48:21.897000-05:00
# 33      EV 2019-12-04 21:39:29.905000-05:00 2019-12-04 21:48:20.958000-05:00
# 39      EV 2019-12-03 22:17:26.903000-05:00 2019-12-03 22:22:22.884000-05:00
# 88      EV 2020-01-04 00:21:44.886000-05:00 2020-01-04 00:30:09.390000-05:00
# 105     EV 2019-12-20 00:30:08.950000-05:00 2019-12-20 00:37:41.874000-05:00
# 96      EV 2019-12-12 00:24:59.242000-05:00 2019-12-12 00:30:49.077000-05:00
# 76      EV 2019-12-11 23:12:00.477000-05:00 2019-12-11 23:23:21.925000-05:00
# 173     PM 2019-12-18 19:42:53.177000-05:00 2019-12-18 19:51:42.445000-05:00
# 126     EV 2019-11-28 00:40:33.286000-05:00 2019-11-28 00:51:27.086000-05:00
# 99      EV 2019-12-07 00:09:26.434000-05:00 2019-12-07 00:17:11.697000-05:00
# 42      EV 2019-11-28 21:39:29.692000-05:00 2019-11-28 21:45:50.126000-05:00
# 4       EV 2019-12-10 20:23:08.954000-05:00 2019-12-10 20:33:44.137000-05:00
# 199     PM 2019-12-10 20:23:08.954000-05:00 2019-12-10 20:33:44.137000-05:00
# 36      EV 2019-12-03 21:49:49.194000-05:00 2019-12-03 22:01:28.843000-05:00
# 100     EV 2019-12-12 00:52:45.569000-05:00 2019-12-12 00:58:16.013000-05:00
# 85      EV 2019-12-19 23:31:38.296000-05:00 2019-12-19 23:40:15.816000-05:00
# 99      EV 2019-12-10 00:35:07.278000-05:00 2019-12-10 00:43:45.349000-05:00
# 15      EV 2019-12-03 20:49:01.429000-05:00 2019-12-03 20:55:18.088000-05:00
# 243     PM 2019-12-03 20:49:01.429000-05:00 2019-12-03 20:55:18.088000-05:00
# 72      EV 2019-11-27 22:29:12.015000-05:00 2019-11-27 22:37:36.804000-05:00
# 160     MD 2019-12-12 15:15:15.140000-05:00 2019-12-12 15:26:47.538000-05:00
# 56      EV 2019-12-13 22:18:59.040000-05:00 2019-12-13 22:29:56.817000-05:00
# 168     PM 2020-01-02 20:19:45.240000-05:00 2020-01-02 20:27:17.350000-05:00
# 1       EV 2020-01-02 20:19:45.240000-05:00 2020-01-02 20:27:17.350000-05:00
# 120     PM 2019-12-30 19:05:01.250000-05:00 2019-12-30 19:20:24.925000-05:00
# 80      EV 2020-01-03 00:23:13.125000-05:00 2020-01-03 00:30:31.128000-05:00
# 198     PM 2019-12-16 20:23:45.182000-05:00 2019-12-16 20:29:34.891000-05:00
# 3       EV 2019-12-16 20:23:45.182000-05:00 2019-12-16 20:29:34.891000-05:00
# 45      EV 2019-12-23 22:09:55.438000-05:00 2019-12-23 22:26:23.664000-05:00
# 117     EV 2019-12-03 00:24:35.470000-05:00 2019-12-03 00:32:15.048000-05:00
# 114     EV 2019-11-27 23:49:19.456000-05:00 2019-11-27 23:58:37.943000-05:00
# 54      EV 2019-12-18 21:42:35.402000-05:00 2019-12-18 21:49:47.422000-05:00
# 102     EV 2019-12-07 00:21:04.060000-05:00 2019-12-07 00:34:53.778000-05:00
# 132     MD 2019-12-16 14:52:23.617000-05:00 2019-12-16 14:58:56.496000-05:00
# 124     EV 2019-11-28 00:14:43.921000-05:00 2019-11-28 00:24:41.186000-05:00
# 48      MD 2019-12-16 12:54:51.219000-05:00 2019-12-16 13:00:29.977000-05:00
# 83      EV 2019-12-04 00:10:29.789000-05:00 2019-12-04 00:17:58.146000-05:00
# 80      EV 2019-12-04 23:38:40.095000-05:00 2019-12-04 23:49:21.713000-05:00
# 103     EV 2019-12-21 00:24:44.907000-05:00 2019-12-21 00:38:18.238000-05:00
# 97      EV 2019-11-30 00:04:50.695000-05:00 2019-11-30 00:11:18.624000-05:00
# 94      EV 2019-12-24 00:18:10.888000-05:00 2019-12-24 00:27:10.828000-05:00
# 100     EV 2019-11-30 00:18:15.746000-05:00 2019-11-30 00:26:03.442000-05:00
#
#       gap  train_id
# 57   2037        14
# 48   1390        13
# 98   1362        32
# 112  1335        42
# 24   1277        11
# 114  1276        42
# 111  1236        37
# 6    1225         4
# 212  1225        56
# 33   1223        17
# 39   1216        16
# 88   1214        33
# 105  1192        39
# 96   1190        36
# 76   1163        27
# 173  1159        43
# 126  1159        37
# 99   1147        35
# 42   1104        13
# 4    1085         3
# 199  1085        56
# 36   1041        15
# 100  1034        39
# 85   1019        33
# 99    997        34
# 15    974         7
# 243   974        56
# 72    967        22
# 160   960        43
# 56    933        21
# 168   932        47
# 1     932         1
# 120   925        33
# 80    913        36
# 198   912        48
# 3     912         2
# 45    908        22
# 117   901        39
# 114   899        32
# 54    895        16
# 102   889        37
# 132   885        37
# 124   882        35
# 48    879        15
# 83    878        30
# 80    874        35
# 103   872        35
# 97    870        36
# 94    869        36
# 100   869        37
