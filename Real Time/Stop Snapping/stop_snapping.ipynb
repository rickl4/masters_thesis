# %%
import geopandas as gpd
import pandas as pd

# %%
new_stations_capture = gpd.read_file('new_stations_capture.geojson')

# %% [markdown]
# # Old Stations

# %%
gtfs_dir = '/Volumes/Data2/RST/notebook/Real Time/gtfs_2019-11-14/'

# %%
station_capture = gpd.read_file('station_capture.geojson')
stops = pd.read_csv('unmatched.csv')

# %%
stops
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 0       262.0                     DANFORTH RD AT KENNEDY RD   -79.260939
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 3       300.0  DUNDAS ST WEST AT DUNDAS WEST OUTER PLATFORM   -79.453253
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# ...       ...                                           ...          ...
# 1377  24237.0                     EASTERN AVE AT CARLAW AVE   -79.339120
# 1378  24238.0                     JARVIS ST AT KING ST EAST   -79.371965
# 1379  24239.0  CALEDONIA RD AT LAWRENCE AVE WEST NORTH SIDE   -79.466533
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
# 1381  24244.0             KING ST WEST AT YORK ST WEST SIDE   -79.383978
#
#       stop_lat_19
# 0       43.714379
# 1       43.634831
# 2       43.655795
# ...

# %%
stations = gpd.read_file('/Volumes/Data2/RST/notebook/GTFS/stop_snapping/GIS Simplify/station_buffer.geojson')
stations
# Out:
#                            name   latitude  longitude  \
# 0        SHEPPARD WEST STATION   43.750204 -79.462781
# 1               WILSON STATION   43.734547 -79.450792
# 2             YORKDALE STATION   43.724595 -79.447693
# 3        LAWRENCE WEST STATION   43.716347 -79.444191
# 4            GLENCAIRN STATION   43.708582 -79.440796
# ..                          ...        ...        ...
# 68       LAWRENCE EAST STATION   43.750475 -79.270436
# 69           ELLESMERE STATION   43.766714 -79.276507
# 70             MIDLAND STATION   43.770400 -79.272179
# 71  SCARBOROUGH CENTRE STATION   43.774648 -79.257285
# 72             MCCOWAN STATION   43.774882 -79.251654
#
#                                              geometry
# 0   MULTIPOLYGON (((623980.262 4845296.150, 623980...
# 1   MULTIPOLYGON (((624978.027 4843575.194, 624978...
# 2   MULTIPOLYGON (((625248.301 4842474.552, 625248...
# 3   MULTIPOLYGON (((625547.567 4841563.784, 625547...
# ...

# %%
stops_1 = stops[~stops['stop_id'].isin(list(station_capture['stop_id']))]
stops_1.to_csv('stops_nostations.csv', index = False)

# %%
stops_1
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 0       262.0                     DANFORTH RD AT KENNEDY RD   -79.260939
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# ...       ...                                           ...          ...
# 1376  24236.0        BATHURST ST AT KING ST WEST SOUTH SIDE   -79.402662
# 1377  24237.0                     EASTERN AVE AT CARLAW AVE   -79.339120
# 1378  24238.0                     JARVIS ST AT KING ST EAST   -79.371965
# 1379  24239.0  CALEDONIA RD AT LAWRENCE AVE WEST NORTH SIDE   -79.466533
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 0       43.714379
# 1       43.634831
# 2       43.655795
# ...

# %% [markdown]
# # New Stations

# %%
new_stations_capture = gpd.read_file('new_stations_capture.geojson')
stops_2 = stops_1[~stops_1['stop_id'].isin(list(new_stations_capture['stop_id']))]
stops_2.to_csv('stops_no-tysse.csv', index = False)

# %%
stops_2
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 0       262.0                     DANFORTH RD AT KENNEDY RD   -79.260939
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# ...       ...                                           ...          ...
# 1376  24236.0        BATHURST ST AT KING ST WEST SOUTH SIDE   -79.402662
# 1377  24237.0                     EASTERN AVE AT CARLAW AVE   -79.339120
# 1378  24238.0                     JARVIS ST AT KING ST EAST   -79.371965
# 1379  24239.0  CALEDONIA RD AT LAWRENCE AVE WEST NORTH SIDE   -79.466533
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 0       43.714379
# 1       43.634831
# 2       43.655795
# ...

# %% [markdown]
# # Major Ints

# %%
major_capture = gpd.read_file('major_capture.geojson')
stops_3 = stops_2[~stops_2['stop_id'].isin(list(major_capture['stop_id']))]
stops_3.to_csv('stops_no-maj.csv', index = False)

# %%
stops_3
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 0       262.0                     DANFORTH RD AT KENNEDY RD   -79.260939
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# ...       ...                                           ...          ...
# 1366  24226.0                     EASTERN AVE AT CARLAW AVE   -79.338834
# 1374  24234.0                   BERKELEY ST AT KING ST EAST   -79.364296
# 1377  24237.0                     EASTERN AVE AT CARLAW AVE   -79.339120
# 1379  24239.0  CALEDONIA RD AT LAWRENCE AVE WEST NORTH SIDE   -79.466533
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 0       43.714379
# 1       43.634831
# 2       43.655795
# ...

# %% [markdown]
# # Maj Min

# %%
maj_min_capture = gpd.read_file('maj_min_capture.geojson')
stops_4 = stops_3[~stops_3['stop_id'].isin(list(maj_min_capture['stop_id']))]
stops_4.to_csv('stops_no-maj-maj_min.csv', index = False)

# %%
stops_4
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 0       262.0                     DANFORTH RD AT KENNEDY RD   -79.260939
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# ...       ...                                           ...          ...
# 1362  24219.0                      VILLIERS ST AT CHERRY ST   -79.353181
# 1363  24220.0                    VILLIERS ST AT MUNITION ST   -79.351263
# 1365  24222.0  COMMISSIONERS ST AT SAULTER STREET EAST SIDE   -79.341777
# 1374  24234.0                   BERKELEY ST AT KING ST EAST   -79.364296
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 0       43.714379
# 1       43.634831
# 2       43.655795
# ...

# %% [markdown]
# # Min Min

# %%
min_min_capture = gpd.read_file('min_min_capture.geojson')
stops_5 = stops_4[~stops_4['stop_id'].isin(list(min_min_capture['stop_id']))]
stops_5.to_csv('stops_no-maj-maj_min-min_min.csv', index = False)

# %%
stops_5
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# 6       366.0                     AIRPORT RD AT BEVERLEY ST   -79.647762
# ...       ...                                           ...          ...
# 1362  24219.0                      VILLIERS ST AT CHERRY ST   -79.353181
# 1363  24220.0                    VILLIERS ST AT MUNITION ST   -79.351263
# 1365  24222.0  COMMISSIONERS ST AT SAULTER STREET EAST SIDE   -79.341777
# 1374  24234.0                   BERKELEY ST AT KING ST EAST   -79.364296
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 1       43.634831
# 2       43.655795
# 4       43.705908
# ...

# %% [markdown]
# # Maj Col

# %%
maj_col_capture = gpd.read_file('maj_col_capture.geojson')
stops_6 = stops_5[~stops_5['stop_id'].isin(list(maj_col_capture['stop_id']))]
stops_6.to_csv('stops_no-maj-maj_min-min_min-maj_col.csv', index = False)

# %%
stops_6
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 1       292.0                DUFFERIN ST AT SPRINGHURST AVE   -79.425646
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 5       318.0              EGLINTON AVE EAST AT EGLINTON SQ   -79.300489
# 6       366.0                     AIRPORT RD AT BEVERLEY ST   -79.647762
# ...       ...                                           ...          ...
# 1362  24219.0                      VILLIERS ST AT CHERRY ST   -79.353181
# 1363  24220.0                    VILLIERS ST AT MUNITION ST   -79.351263
# 1365  24222.0  COMMISSIONERS ST AT SAULTER STREET EAST SIDE   -79.341777
# 1374  24234.0                   BERKELEY ST AT KING ST EAST   -79.364296
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 1       43.634831
# 2       43.655795
# 4       43.705908
# ...

# %% [markdown]
# # Filtering Int Remaining

# %%
int_remaining = gpd.read_file('int_remaining_buffer_touches.geojson')

# %%
int_remaining = int_remaining[~int_remaining['shape_id'].isna()]
int_remaining.to_file('int_remaining_buffer_cropped.geojson', driver = 'GeoJSON')

# %% [markdown]
# # Remaining Intersections

# %%
remaining_capture = gpd.read_file('int_remaining_capture.geojson')
stops_7 = stops_6[~stops_6['stop_id'].isin(list(remaining_capture['stop_id']))]

# %%
stops_7
# Out:
#       stop_id                                  stop_name_19  stop_lon_19  \
# 2       294.0                                 DUFFERIN MALL   -79.434031
# 4       307.0                         EAST YORK TOWN CENTRE   -79.347132
# 6       366.0                     AIRPORT RD AT BEVERLEY ST   -79.647762
# 7       367.0            AIRPORT RD AT BRESLER DR WEST SIDE   -79.607576
# 8       368.0                      AIRPORT RD AT BRESLER DR   -79.606403
# ...       ...                                           ...          ...
# 1349  24205.0                           1189 HUNTINGWOOD DR   -79.277886
# 1351  24207.0                               1965 BRIMLEY RD   -79.266940
# 1352  24208.0                               1994 BRIMLEY RD   -79.267363
# 1365  24222.0  COMMISSIONERS ST AT SAULTER STREET EAST SIDE   -79.341777
# 1380  24240.0                     KNOB HILL DR AT WESTON RD   -79.534253
#
#       stop_lat_19
# 2       43.655795
# 4       43.705908
# 6       43.707577
# ...
