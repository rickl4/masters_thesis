# %%
import pandas as pd
import numpy as np
import datetime

# %%
def process_trip(single_trip):
    
    single_trip = single_trip[single_trip['timint']<2]
    arrivals = single_trip[['station_char']].drop_duplicates()
    
    arrival_max = single_trip.sort_values(by = 'request_date', ascending = False)
    arrival_max = arrival_max.drop_duplicates(subset = ['station_char'])[['station_char', 'estimated_arrival']]


    arrivals_at_station = single_trip[single_trip['timint']==0]
    arrivals_at_station = arrivals_at_station.sort_values(by = 'estimated_arrival')
    arrivals_at_station  = arrivals_at_station.drop_duplicates(subset = ['station_char'])[['station_char', 'estimated_arrival']]

    arrivals = arrivals.merge(arrival_max, how = 'left')

    arrivals_at_station = arrivals_at_station.rename(columns = {'estimated_arrival':'at_station_time'})
    arrivals = arrivals.merge(arrivals_at_station, how = 'left')
    arrivals['arrival'] = True
    
    arrivals['arrival_time'] = np.where(arrivals['at_station_time'].isna(),
                                        arrivals['estimated_arrival'], arrivals['at_station_time'])



    arrivals = arrivals.sort_values(by = 'estimated_arrival').reset_index(drop = True)
    
    arrivals = arrivals[['station_char', 'arrival', 'arrival_time']].rename(columns =
                                                                        {'arrival_time':'estimated_arrival'})
    if len(arrivals) != 0:
        single_trip = single_trip.merge(arrivals)
    else:
        return -1 # no eligible arrivals, continue to next trip

    single_trip = single_trip.sort_values(by = 'estimated_arrival')
    
    single_trip = single_trip[['station_char', 'subwayline', 'timint','stationid', 'traindirection', 'trip','trainid',
                 'estimated_arrival', 'arrival']]
    
    single_trip = single_trip.reset_index().merge(single_trip.shift(-1).reset_index()[['station_char',
                                                                                       'estimated_arrival','stationid',
                                                                                       'index']], 
                                left_on = 'index', right_on = 'index', suffixes = ['_o', '_d'])
    single_trip = single_trip.dropna()
    return single_trip

# %%
df = pd.read_csv('cleaned_subway/raw_subway_2019-11-29_PM.csv')

# %%
df['request_date'] = pd.to_datetime(df['request_date'])

# %%
df = df.sort_values(by = 'timint')

# %%
stn_lookup = pd.read_csv('train_arrival_stations_lookup.csv')

# %%
df['platformid'] = df['station_char'].str[3]

# %%
df
# Out:
#         requestid           id station_char subwayline     timint  \
# 115970     738032  34288841325         QUN2        YUS   0.000000
# 42287      687227  34285606344         YIE2       SHEP   0.000000
# 42284      687227  34285606050         SHP1        YUS   0.000000
# 118399     740796  34288146754         OSS1         BD   0.000000
# 131594     750754  34287205166         PAP1         BD   0.000000
# ...           ...          ...          ...        ...        ...
# 36233      684203  34287938682         KEN1         BD  17.334796
# 15455      668422  34282700263         WIL1        YUS  17.460351
# 115411     737942  34282381405         WIL1        YUS  17.460351
# 38955      685945  34282764416         WIL1        YUS  17.715351
# 36234      684203  34287938683         KEN1         BD  18.301702
#
#        traindirection  trainid train_message  stationid  lineid  \
# 115970          South      196     AtStation         18       1
# 42287            West      814       Delayed         30       1
# 42284           North      115     AtStation         30       1
# 118399           East      222     AtStation         44       2
# 131594           East      241     AtStation         55       2
# ...               ...      ...           ...        ...     ...
# 36233            East      206      Arriving         63       2
# 15455           North      158      Arriving          2       1
# 115411          North      152      Arriving          2       1
# 38955           North      159      Arriving          2       1
# 36234            East      207      Arriving         63       2
#
#                 create_date  pollid                     request_date  \
# 115970  2019-11-29 20:59:43   10417 2019-11-29 20:59:43.688017-05:00
# 42287   2019-11-29 18:28:44    9705 2019-11-29 18:28:43.612801-05:00
# 42284   2019-11-29 18:28:44    9705 2019-11-29 18:28:43.612801-05:00
# 118399  2019-11-29 20:24:52   10454 2019-11-29 20:24:51.302882-05:00
# 131594  2019-11-29 19:41:49   10592 2019-11-29 19:41:51.291830-05:00
# ...                     ...     ...                              ...
# 36233   2019-11-29 20:14:49    9663 2019-11-29 20:14:51.294143-05:00
# 15455   2019-11-29 16:15:43    9439 2019-11-29 16:15:43.598633-05:00
# 115411  2019-11-29 16:01:42   10416 2019-11-29 16:01:43.904510-05:00
# 38955   2019-11-29 16:18:42    9688 2019-11-29 16:18:43.638384-05:00
# 36234   2019-11-29 20:14:49    9663 2019-11-29 20:14:51.294143-05:00
#
#               date  hour  dow period platformid
# 115970  2019-11-29    20    4     PM          2
# 42287   2019-11-29    18    4     PM          2
# 42284   2019-11-29    18    4     PM          1
# 118399  2019-11-29    20    4     PM          1
# 131594  2019-11-29    19    4     PM          1
# ...            ...   ...  ...    ...        ...
# 36233   2019-11-29    20    4     PM          1
# 15455   2019-11-29    16    4     PM          1
# 115411  2019-11-29    16    4     PM          1
# 38955   2019-11-29    16    4     PM          1
# 36234   2019-11-29    20    4     PM          1
#
# [135739 rows x 18 columns]

# %% [markdown]
# # Filtering for only the most recent data in a request
#
# Since each request has multiple train arrival times.
#
# We're filtering on `station_char` and `requestid`. This might cause an issue with terminus, but we'll deal with it later.

# %%
df_newest = df.drop_duplicates(subset = ['requestid', 'station_char'])

# %%
train_list = []
for line in list(df_newest['subwayline'].drop_duplicates()):
    df_line = df_newest[df_newest['subwayline'] == line]
    
    train_ids = df_line['trainid'].drop_duplicates()
    
    for train_id in train_ids:
        
        single_train = df_line[df_line['trainid'] == train_id]
        
        single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')

        single_train = single_train.sort_values(by = 'request_date')

        single_train['trip'] = ((single_train['traindirection'] != single_train['traindirection'].shift(1))
                               | ((single_train['request_date'] - single_train['request_date'].shift(1)).dt.seconds > 1800)
                               ).cumsum() - 1        
        trip_num = single_train['trip'].max()
        
        
        arrival_list = []
        arrival_limit = None
        for i in range(trip_num + 1):
            if i == 0:
                current_arrivals = process_trip(single_train[single_train['trip'] == i])
                if isinstance(current_arrivals, int):
                    print('cont')
                    continue

            elif isinstance(current_arrivals, int): # when the previous current arrivals does not return a result
                current_arrivals = process_trip(single_train[single_train['trip'] == i])
                if isinstance(current_arrivals, int): # if the successives trip still does not return a result
                    print('cont')
                    continue
            else:
                
                if i < trip_num:
                    next_arrivals = process_trip(single_train[single_train['trip'] == i + 1])
                try:
                    arrival_limit = next_arrivals.head(1)[['estimated_arrival_d']].iloc[0,0] - datetime.timedelta(seconds = 45)

                except: # if the next trip doesn't return a result, then the arrival limit id not used

                    if len(current_arrivals['station_char_d']) == 0:
                        pass
                    else:
                        arrival_limit = current_arrivals.tail(1)[['estimated_arrival_d']].iloc[0,0] + datetime.timedelta(seconds = 45)

                if len(current_arrivals['station_char_d']) == 1:
                    pass
                elif len(current_arrivals['station_char_d']) == 0:
                    pass

                elif i < trip_num:

                    current_arrivals = current_arrivals[current_arrivals['estimated_arrival_d'] < arrival_limit]
                else:
                    pass
                if i < trip_num:
                    past_arrivals = current_arrivals
                    current_arrivals = next_arrivals
                else:
                    pass
            try:
                arrival_list.append(past_arrivals.copy())
            except:
                arrival_list.append(current_arrivals.copy())





        if len(arrival_list) == 0:
            continue
        else:
            arrival_trip = pd.concat(arrival_list)
        
        if arrival_trip['estimated_arrival_d'].max().hour < 11:
            if arrival_trip['subwayline'].drop_duplicates().iloc[0] == 'BD':
                cutoff = arrival_trip[arrival_trip['stationid_d'] == 55]['estimated_arrival_d'].max()

            elif (arrival_trip['subwayline'].drop_duplicates().iloc[0] == 'YUS') & (arrival_trip.tail(1)['stationid_d'].iloc[0] == 80):
                cutoff = arrival_trip[arrival_trip['stationid_d'] == 80]['estimated_arrival_d'].max()

            elif arrival_trip['subwayline'].drop_duplicates().iloc[0] == 'YUS':
                cutoff = arrival_trip[arrival_trip['stationid_d'] == 1]['estimated_arrival_d'].max()
            else:
                cutoff = arrival_trip['estimated_arrival_d'].max()
        else:
            cutoff = arrival_trip['estimated_arrival_d'].max()

        arrival_trip = arrival_trip[arrival_trip['estimated_arrival_d'] <= cutoff]


        arrival_trip = arrival_trip.reset_index(drop = True)
        
        arrival_trip = arrival_trip.merge(stn_lookup[['station_char', 'sequence']], left_on = ['station_char_o'], 
                   right_on = ['station_char']).drop(columns = ['station_char']).rename(
            columns = {'sequence':'sequence_o'})

        arrival_trip = arrival_trip.merge(stn_lookup[['station_char', 'sequence']], left_on = ['station_char_d'], 
                           right_on = ['station_char']).drop(columns = ['station_char']).rename(
            columns = {'sequence':'sequence_d'})
        
        train_list.append(arrival_trip)
# Out:
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# cont
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# ...
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# cont
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_35523/623153585.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_train['estimated_arrival'] = single_train['request_date'] + pd.to_timedelta(single_train['timint'], 'm')

# %%
train_df = pd.concat(train_list)

# %%
len(train_df)
# Out:
# 12380

# %%
train_df['cost'] = (train_df['estimated_arrival_d'] - train_df['estimated_arrival_o']).dt.seconds/60
train_df = train_df[train_df['cost']<60]
len(train_df)
# Out:
# 12380

# %%
abs(train_df['sequence_o'] - train_df['sequence_d'])
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#     ..
# 3    2
# 4    1
# 5    1
# 6    2
# 7    1
# Length: 12380, dtype: int64

# %%
train_df[train_df['trainid'] == 196]
# Out:
#    index station_char_o subwayline    timint  stationid_o traindirection  \
# 0      0           STC2        YUS  0.387822           25          South
# 1      1           SUM2        YUS  0.000000           24          South
# 2      2           ROS2        YUS  0.000000           23          South
# 3      3           BLO2        YUS  0.000000           22          South
# 4      4           WEL2        YUS  0.000000           21          South
# 5      5           COL2        YUS  0.000000           20          South
# 6      6           DUN2        YUS  0.000000           19          South
#
#    trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 0     0      196 2019-11-29 20:51:06.956848840-05:00     True           SUM2
# 1     0      196    2019-11-29 20:52:43.444845-05:00     True           ROS2
# 2     0      196    2019-11-29 20:53:43.988218-05:00     True           BLO2
# 3     0      196    2019-11-29 20:55:43.685313-05:00     True           WEL2
# 4     0      196    2019-11-29 20:56:43.574773-05:00     True           COL2
# 5     0      196    2019-11-29 20:57:43.346175-05:00     True           DUN2
# 6     0      196    2019-11-29 20:58:43.276039-05:00     True           QUN2
#
#                estimated_arrival_d  stationid_d  sequence_o  sequence_d  \
# 0 2019-11-29 20:52:43.444845-05:00         24.0          31          30
# 1 2019-11-29 20:53:43.988218-05:00         23.0          30          29
# 2 2019-11-29 20:55:43.685313-05:00         22.0          29          28
# 3 2019-11-29 20:56:43.574773-05:00         21.0          28          27
# 4 2019-11-29 20:57:43.346175-05:00         20.0          27          26
# 5 2019-11-29 20:58:43.276039-05:00         19.0          26          25
# 6 2019-11-29 20:59:43.688017-05:00         18.0          25          24
#
#        cost
# 0  1.600000
# 1  1.000000
# 2  1.983333
# 3  0.983333
# 4  0.983333
# 5  0.983333
# 6  1.000000

# %%
train_df[abs(train_df['sequence_o'] - train_df['sequence_d']) == 0]
# Out:
#     index station_char_o subwayline    timint  stationid_o traindirection  \
# 96     32           VMC2        YUS  0.964922           80          South
# 97     32           VMC2        YUS  0.964922           80          South
# 99     37           VMC2        YUS  0.937352           80          South
# 92     36           VMC1        YUS  0.937352           80          South
# 2      37           VMC1        YUS  0.937352           80          South
# ..    ...            ...        ...       ...          ...            ...
# 0       0           KIP2         BD  0.254518           33           East
# 30      0           KIP1         BD  1.265017           33           West
# 32      0           KIP2         BD  0.254518           33           East
# 0       0           KEN2         BD  0.566031           63           East
# 0       0           KEN2         BD  0.566031           63           East
#
#     trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 96     0      115 2019-11-29 17:07:48.690675140-05:00     True           VMC1
# 97     0      115 2019-11-29 17:07:48.690675140-05:00     True           VMC1
# 99     3      123 2019-11-29 20:16:39.753829860-05:00     True           VMC1
# 92     2      171 2019-11-29 19:19:40.165872860-05:00     True           VMC2
# 2      3      133 2019-11-29 20:40:39.843660860-05:00     True           VMC2
# ..   ...      ...                                 ...      ...            ...
# 0      3       29 2019-11-29 18:12:58.729533419-05:00     True           KIP1
# 30     2      231 2019-11-29 18:18:06.673903200-05:00     True           KIP2
# 32     3      231 2019-11-29 18:17:59.154223419-05:00     True           KIP1
# 0      0       34 2019-11-29 19:09:25.243803979-05:00     True           KEN1
# 0      0       34 2019-11-29 19:09:25.243803979-05:00     True           KEN1
#
#                    estimated_arrival_d  stationid_d  sequence_o  sequence_d  \
# 96 2019-11-29 17:09:48.695254140-05:00         80.0           1           1
# 97 2019-11-29 17:09:48.695254140-05:00         80.0           1           1
# 99 2019-11-29 20:16:39.753829860-05:00         80.0           1           1
# 92    2019-11-29 19:22:43.545539-05:00         80.0           1           1
# 2     2019-11-29 20:40:50.715629-05:00         80.0           1           1
# ..                                 ...          ...         ...         ...
# 0     2019-11-29 18:13:43.597100-05:00         33.0          39          39
# 30 2019-11-29 18:18:06.673903200-05:00         33.0          39          39
# 32    2019-11-29 18:18:43.773433-05:00         33.0          39          39
# 0     2019-11-29 19:09:51.283696-05:00         63.0          69          69
# 0     2019-11-29 19:09:51.283696-05:00         63.0          69          69
#
#         cost
# 96  2.000000
# 97  2.000000
# 99  0.000000
# 92  3.050000
# 2   0.166667
# ..       ...
# 0   0.733333
# 30  0.000000
# 32  0.733333
# 0   0.433333
# 0   0.433333
#
# [109 rows x 16 columns]

# %%
train_df[abs(train_df['sequence_o'] - train_df['sequence_d']) > 1].reset_index(drop = True)
# Out:
#     index station_char_o subwayline    timint  stationid_o traindirection  \
# 0       0           KEN2         BD  0.000000           63           West
# 1       1           KIP1         BD  0.000000           33           East
# 2       0           KIP1         BD  0.000000           33           East
# 3       1           RYK1         BD  0.000000           35           East
# 4       2           VPK2         BD  0.686247           61           West
# 5       4           COX2         BD  0.000000           58           West
# 6       5           MST2         BD  0.291297           60           West
# 7      12           BAT1         BD  1.021368           46           East
# 8      17           SHE1         BD  1.119917           51           East
# 9       4           WDB2         BD  1.555969           59           West
# 10      4           BRD1         BD  0.381293           53           East
# 11     22           DNW2         BD  0.000000           41           West
# 12      0           WAR2         BD  0.000000           62           West
# 13     10           SHE2         BD  0.999625           51           West
# 14      9           PAP2         BD  0.000000           55           West
# 15      0           KEN2         BD  0.000000           63           West
# 16      4           BRD1         BD  0.000000           53           East
# 17      0           BRD1         BD  0.717745           53           East
# 18      0           WAR2         BD  0.273148           62           West
# 19      6           DON1         BD  0.000000           56           East
# 20     18           QPK2        YUS  1.419594           12          South
# 21      5           EGL2        YUS  0.518259           27          South
# 22      7           DAV2        YUS  0.000000           26          South
# 23     25           LAW1        YUS  0.000000           28          North
# 24      2           YKM2        YUS  0.000000           29          South
# 25      4           DAV2        YUS  0.891763           26          South
# 26     31           SHW2        YUS  0.000000            1          South
# 27     30           STC1        YUS  0.000000           25          North
# 28     29           YKD2        YUS  0.000000            3          South
# 29     31           DNP2        YUS  0.000000           75          South
# 30     29           WIL2        YUS  1.483779            2          South
# 31     34           YKM1        YUS  0.000000           29          North
# 32     30           WIL2        YUS  1.483779            2          South
# 33      0           VMC1        YUS  0.000000           80          North
# 34      7           QPK1        YUS  0.000000           12          North
# 35      9           STP1        YUS  0.000000           13          North
# 36     29           YKM1        YUS  1.419412           29          North
# 37     35           SHP1        YUS  1.196489           64          North
# 38     30           WIL2        YUS  0.010026            2          South
# 39      2           LAW1        YUS  0.320936           28          North
# 40     26           GCN2        YUS  1.906281            5          South
# 41     29           SHP1        YUS  1.614842           64          North
# 42     30           STC1        YUS  0.793473           25          North
# 43     11           YKM1        YUS  0.000000           29          North
# 44     19           QPK2        YUS  1.419594           12          South
# 45     29           WIL2        YUS  0.000000            2          South
# 46     31           SHW2        YUS  0.000000            1          South
# 47     34           YKM1        YUS  0.000000           29          North
# 48      4           FIW1        YUS  0.000000           76          North
# 49     29           WIL2        YUS  0.000000            2          South
# 50      1           NYC2        YUS  0.000000           31          South
# 51     23           LAW1        YUS  0.000000           28          North
# 52      8           DNP2        YUS  0.000000           75          South
# 53     25           SHP1        YUS  0.322870           64          North
# 54     13           LAW1        YUS  0.320936           28          North
# 55     29           WIL2        YUS  1.483779            2          South
# 56     32           YKM1        YUS  1.419412           29          North
# 57     27           YKM1        YUS  0.000000           29          North
# 58      3           FIW1        YUS  0.000000           76          North
# 59     11           YKM1        YUS  0.370541           29          North
#
#     trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 
# 38   5.700000
# 39   6.666667
# 40   0.083333
# 41   1.916667
# 42  22.200000
# 43   7.000000
# 44  13.300000
# 45   0.983333
# 46   6.316667
# 47   8.000000
# 48   5.733333
# 49   6.700000
# 50   6.000000
# 51   5.983333
# 52   5.633333
# 53   3.550000
# 54  12.666667
# 55   1.500000
# 56   1.566667
# 57   8.000000
# 58   4.983333
# 59  11.616667

# %%
train_df.sort_values(by = 'cost', ascending = False).head(50)
# Out:
#      index station_char_o subwayline    timint  stationid_o traindirection  \
# 11      11           LAW1        YUS  0.000000           28          North
# 60      37           VMC2        YUS  1.565961           80          South
# 3       30           STC1        YUS  0.000000           25          North
# 30       1           KIP1         BD  0.000000           33           East
# 6        6           DON2         BD  0.000000           56           West
# 5        5           GWD2         BD  0.000000           57           West
# 5        5           COX2         BD  0.000000           58           West
# 11       5           GWD2         BD  0.000000           57           West
# 109     34           YKM1        YUS  0.000000           29          North
# 15      30           STC1        YUS  0.793473           25          North
# 5        5           GWD2         BD  0.000000           57           West
# 0        0           WAR2         BD  0.000000           62           West
# 18       4           BRD1         BD  0.000000           53           East
# 14       6           DON2         BD  0.000000           56           West
# 22      10           PAP1         BD  0.000000           55           East
# 13       7           CFK1         BD  0.000000           52           East
# 32       9           CHE1         BD  0.000000           54           East
# 19      16           VPK1         BD  0.000000           61           East
# 84      35           SHP1        YUS  0.000000           30          North
# 4        4           COX2         BD  0.000000           58           West
# 13      13           BAU2         BD  0.000000           49           West
# 84       0           FIN2        YUS  0.000000           32          South
# 86      32           DNP2        YUS  0.000000           75          South
# 28      14           SGL2         BD  0.000000           10           West
# 46       8           BRD1         BD  0.000000           53           East
# 0        0           KEL1         BD  0.000000           40           East
# 68       6           SHE1         BD  0.000000           51           East
# 34      17           CHR2         BD  0.000000           45           West
# 16      16           BAT2         BD  0.000000           46           West
# 18       0           KEN2         BD  0.000000           63           West
# 15      15           BAT2         BD  0.000000           46           West
# 86      33           YKM1        YUS  0.000000           29          North
# 68       0           KEN2         BD  0.000000           63           West
# 71      19           EGL1        YUS  0.000000           27          North
# 28      28           NYC1        YUS  0.000000           31          North
# 96      23           LAW1        YUS  0.000000           28          North
# 84      32           EGL1        YUS  0.126104           27          North
# 31      19           QPK2        YUS  1.419594           12          South
# 32       7           CFK1         BD  0.000000           52           East
# 85      31           EGL1        YUS  0.000000           27          North
# 53      29           NYC1        YUS  0.000000           31          North
# 94      23           LAW1        YUS  0.000000           28          North
# 63       1           SHP2        YUS  0.000000           30          South
# 20      11           SHE2         BD  0.000000           51           West
# 26      13           LAW1        YUS  0.320936           28          North
# 61      32           LAW1        YUS  0.320936           28          North
# 107     35           SHP1        YUS  0.000000           30          North
# 16      16           BSP2         BD  0.000000            9           West
# 19      19           OSS2         BD  0.000000           44           West
# 57      17           CHR2         BD  0.000000           45           West
#
#      trip  trainid                 estimated_arrival_o  arrival  \
# 11      0      198    2019-12-02 07:21:52.730326-05:00     True
# 60      1      112 2019-12-02 09:35:11.776734720-05:00     True
# 16            BAT2    2019-12-02 07:49:44.732877-05:00         46.0
# 19            DUF2    2019-12-02 10:29:45.520291-05:00         43.0
# 57            OSS2    2019-12-02 10:33:45.522075-05:00         44.0
#
#      sequence_o  sequence_d       cost
# 11           34          35  40.483333
# 60            1           1  40.383333
# 3            31          37  34.000000
# 30           39          57  27.983333
# 6            62          61  27.000000
# 5            63          62  25.000000
# 5            64          63  24.000000
# 11           63          62  23.066667
# 109          35          37  23.000000
# 15           31          35  22.200000
# 5            63          62  22.000000
# 0            68          60  21.000000
# 18           59          60  20.300000
# 14           62          61  20.000000
# 22           61          62  19.000000
# 13           58          59  18.983333
# 32           60          61  18.983333
# 19           67          68  18.000000
# 84           36          37  17.983333
# 4            64          63  17.000000
# 13           55          54  17.000000
# 84           38          37  16.366667
# 86            6           5  16.000000
# 28           54          53  15.983333
# 46           59          60  15.716667
# 0            46          47  15.283333
# 68           57          58  15.116667
# 34           51          50  15.000000
# 16           52          51  15.000000
# 18           69          59  15.000000
# 15           52          51  14.300000
# 86           35          36  14.000000
# 68           69          68  14.000000
# 71           33          34  14.000000
# 28           37          38  13.983333
# 96           34          35  13.983333
# 84           33          34  13.866667
# 31           18          12  13.300000
# 32           58          59  13.000000
# 85           33          34  13.000000
# 53           37          38  12.983333
# 94           34          35  12.983333
# 63           36          35  12.983333
# 20           57          56  12.866667
# 26           34          36  12.666667
# 61           34          35  12.666667
# 107          36          37  12.233333
# 16           53          52  12.116667
# 19           50          49  12.000000
# 57           51          50  12.000000

# %%
train_df[(train_df['cost'] > 0.4) & (train_df['cost'] < 15)]
# Out:
#     index station_char_o subwayline    timint  stationid_o traindirection  \
# 0       0           BYV1       SHEP  0.000000           65           East
# 1       1           BSS1       SHEP  0.895973           66           East
# 2       2           LES1       SHEP  0.000000           67           East
# 4       0           DML2       SHEP  0.000000           68           West
# 5       1           LES2       SHEP  0.000000           67           West
# ..    ...            ...        ...       ...          ...            ...
# 1       1           PVL1        YUS  0.227492           78          North
# 2       2           YUN1        YUS  0.000000           77          North
# 3       3           FIW1        YUS  0.000000           76          North
# 4       4           DNP1        YUS  0.000000           75          North
# 0       0           SHW2        YUS  0.158990            1          South
#
#     trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 0      0      463    2019-11-28 07:01:51.417028-05:00     True           BSS1
# 1      0      463 2019-11-28 07:03:45.173927240-05:00     True           LES1
# 2      0      463    2019-11-28 07:04:51.416831-05:00     True           DML1
# 4      1      463    2019-11-28 07:07:51.419204-05:00     True           LES2
# 5      1      463    2019-11-28 07:12:51.427952-05:00     True           BSS2
# ..   ...      ...                                 ...      ...            ...
# 1      0       52 2019-11-28 10:54:57.147737420-05:00     True           YUN1
# 2      0       52    2019-11-28 10:56:43.655887-05:00     True           FIW1
# 3      0       52    2019-11-28 10:58:43.494615-05:00     True           DNP1
# 4      0       52    2019-11-28 11:01:43.995897-05:00     True           SHW1
# 0      1      199 2019-11-28 11:56:53.243854680-05:00     True           DNP2
#
#                    estimated_arrival_d  stationid_d      cost
# 0  2019-11-28 07:03:45.173927240-05:00         66.0  1.883333
# 1     2019-11-28 07:04:51.416831-05:00         67.0  1.100000
# 2  2019-11-28 07:07:31.888566640-05:00         68.0  2.666667
# 4     2019-11-28 07:12:51.427952-05:00         67.0  5.000000
# 5  2019-11-28 07:14:46.391402980-05:00         66.0  1.900000
# ..                                 ...          ...       ...
# 1     2019-11-28 10:56:43.655887-05:00         77.0  1.766667
# 2     2019-11-28 10:58:43.494615-05:00         76.0  1.983333
# 3     2019-11-28 11:01:43.995897-05:00         75.0  3.000000
# 4  2019-11-28 11:04:35.538133500-05:00          1.0  2.850000
# 0  2019-11-28 11:59:26.011504840-05:00         75.0  2.533333
#
# [12066 rows x 14 columns]

# %%
train_df[(train_df['cost'] < 0.4)].sort_values(by = 'cost')
# Out:
#      index station_char_o subwayline    timint  stationid_o traindirection  \
# 3        3           DML1       SHEP  0.674497           68           East
# 46      29           KIP2         BD  0.862818           33           West
# 31      30           KIP1         BD  0.862818           33           West
# 0        0           KIP1         BD  0.604911           33           West
# 75      31           KEN1         BD  0.820667           63           East
# ..     ...            ...        ...       ...          ...            ...
# 70       1           YIE1       SHEP  0.000000           64           East
# 91       0           YIE2       SHEP  0.503356           64           East
# 115      0           YIE2       SHEP  0.503356           64           East
# 52       0           YIE2       SHEP  0.503356           64           East
# 65      30           KIP1         BD  0.604911           33           West
#
#      trip  trainid                 estimated_arrival_o  arrival  \
# 3       0      463 2019-11-28 07:07:31.888566640-05:00     True
# 46      3      203 2019-11-28 08:29:43.113328720-05:00     True
# 31      1      236 2019-11-28 07:54:43.099116720-05:00     True
# 0       0      213 2019-11-28 07:01:20.270808140-05:00     True
# 75      2      201 2019-11-28 09:17:40.594182240-05:00     True
# ..    ...      ...                                 ...      ...
# 70     16      462    2019-11-28 09:46:51.367945-05:00     True
# 91     23      461 2019-11-28 11:09:20.804812300-05:00     True
# 115    26      462 2019-11-28 11:37:20.823004300-05:00     True
# 52     12      462 2019-11-28 09:03:21.549763300-05:00     True
# 65      2      219 2019-11-28 09:01:19.885645140-05:00     True
#
#     station_char_d                 estimated_arrival_d  stationid_d      cost
# 3             DML2 2019-11-28 07:07:31.888566640-05:00         68.0  0.000000
# 46            KIP1 2019-11-28 08:29:43.113328720-05:00         33.0  0.000000
# 31            KIP2 2019-11-28 07:54:43.099116720-05:00         33.0  0.000000
# 0             KIP2 2019-11-28 07:01:20.270808140-05:00         33.0  0.000000
# 75            KEN2 2019-11-28 09:17:40.594182240-05:00         63.0  0.000000
# ..             ...                                 ...          ...       ...
# 70            YIE2 2019-11-28 09:47:13.844385300-05:00         30.0  0.366667
# 91            YIE1    2019-11-28 11:09:43.666333-05:00         30.0  0.366667
# 115           YIE1    2019-11-28 11:37:43.725591-05:00         30.0  0.366667
# 52            YIE1    2019-11-28 09:03:43.842750-05:00         30.0  0.366667
# 65            KIP2    2019-11-28 09:01:43.787570-05:00         33.0  0.383333
#
# [116 rows x 14 columns]

# %%
train_df[(train_df['station_char_o'].str[0:3] == train_df['station_char_d'].str[0:3])]
# Out:
#     index station_char_o subwayline    timint  stationid_o traindirection  \
# 3       3           DML1       SHEP  0.674497           68           East
# 7       0           YIE2       SHEP  0.503356           64           East
# 11      0           DML1       SHEP  0.418792           68           West
# 16      5           YIE2       SHEP  1.006711           30           West
# 21      4           DML2       SHEP  0.551678           68           East
# ..    ...            ...        ...       ...          ...            ...
# 76     36           VMC1        YUS  0.961779           80          South
# 66     36           VMC1        YUS  0.961779           80          South
# 40      9           VMC2        YUS  0.961779           80          South
# 17     17           VMC1        YUS  0.357577           80          South
# 5       5           VMC1        YUS  0.961779           80          South
#
#     trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 3      0      463 2019-11-28 07:07:31.888566640-05:00     True           DML2
# 7      2      463 2019-11-28 07:19:21.630879300-05:00     True           YIE1
# 11     3      463 2019-11-28 07:29:16.561617760-05:00     True           DML2
# 16     3      463 2019-11-28 07:40:51.850606540-05:00     True           YIE1
# 21     4      463 2019-11-28 07:50:24.412125120-05:00     True           DML1
# ..   ...      ...                                 ...      ...            ...
# 76     2      135 2019-11-28 10:01:48.822732120-05:00     True           VMC2
# 66     1      139 2019-11-28 10:12:41.229193120-05:00     True           VMC2
# 40     5      123 2019-11-28 09:43:41.252144120-05:00     True           VMC1
# 17     0      514 2019-11-28 11:05:21.052241820-05:00     True           VMC2
# 5      1       45 2019-11-28 10:35:41.300874120-05:00     True           VMC2
#
#                    estimated_arrival_d  stationid_d      cost
# 3  2019-11-28 07:07:31.888566640-05:00         68.0  0.000000
# 7     2019-11-28 07:19:43.566730-05:00         30.0  0.350000
# 11    2019-11-28 07:29:51.434776-05:00         68.0  0.566667
# 16 2019-11-28 07:40:51.850606540-05:00         30.0  0.000000
# 21    2019-11-28 07:50:51.310334-05:00         68.0  0.433333
# ..                                 ...          ...       ...
# 76    2019-11-28 10:04:43.825634-05:00         80.0  2.916667
# 66    2019-11-28 10:15:43.817663-05:00         80.0  3.033333
# 40 2019-11-28 09:45:05.184776820-05:00         80.0  1.383333
# 17    2019-11-28 11:07:43.441701-05:00         80.0  2.366667
# 5  2019-11-28 10:35:41.300874120-05:00         80.0  0.000000
#
# [204 rows x 14 columns]

# %%
train_df[(train_df['station_char_o'].str[0:3] != train_df['station_char_d'].str[0:3]) & (train_df['cost'] < 0.4 )].reset_index(drop = True)
# Out:
#     index station_char_o subwayline    timint  stationid_o traindirection  \
# 0       1           BSS2       SHEP  0.916107           66           West
# 1       2           BYV1       SHEP  1.278523           65           East
# 2      25           RUN2         BD  0.801858           38           West
# 3      15           MUS2        YUS  0.000000           11          South
# 4      19           STA2        YUS  0.667184           15          South
# 5      12           BLO2        YUS  1.943810           50          South
# 6      20           GCN2        YUS  1.119987            5          South
# 7      21           OSG2        YUS  1.181165           14          South
# 8      14           BLO2        YUS  0.000000           22          South
# 9      15           DUP2        YUS  0.745118            8          South
# 10      9           DAV2        YUS  1.684681           26          South
# 11     13           HWY2        YUS  0.000000           79          South
#
#     trip  trainid                 estimated_arrival_o  arrival station_char_d  \
# 0     11      463 2019-11-28 09:05:46.313604980-05:00     True           BYV2
# 1     11      461 2019-11-28 09:03:08.058430400-05:00     True           BSS1
# 2      2      213 2019-11-28 08:38:31.581716720-05:00     True           RYK2
# 3      2      151    2019-11-28 09:39:43.558247-05:00     True           KNG2
# 4      2      151 2019-11-28 09:44:23.789823900-05:00     True           DUP2
# 5      2      158 2019-11-28 09:57:40.222264380-05:00     True           DUP2
# 6      2      158 2019-11-28 10:07:50.962539260-05:00     True           STA2
# 7      2      158 2019-11-28 10:08:54.327205860-05:00     True           LWW2
# 8      1      134    2019-11-28 08:53:43.477477-05:00     True           SPA2
# 9      1      134 2019-11-28 08:55:28.079760820-05:00     True           WEL2
# 10     4      145 2019-11-28 09:16:24.634327920-05:00     True           PVL2
# 11     4      145    2019-11-28 09:18:43.713032-05:00     True           STC2
#
#                    estimated_arrival_d  stationid_d      cost
# 0     2019-11-28 09:05:51.348379-05:00         65.0  0.083333
# 1  2019-11-28 09:03:08.984957920-05:00         66.0  0.000000
# 2     2019-11-28 08:38:43.977257-05:00         35.0  0.200000
# 3  2019-11-28 09:39:56.879535740-05:00         17.0  0.216667
# 4     2019-11-28 09:44:43.719085-05:00          8.0  0.316667
# 5  2019-11-28 09:57:46.118908740-05:00          8.0  0.083333
# 6  2019-11-28 10:08:11.148869620-05:00         15.0  0.333333
# 7  2019-11-28 10:09:12.044801320-05:00          4.0  0.283333
# 8  2019-11-28 08:53:49.356477840-05:00         47.0  0.083333
# 9     2019-11-28 08:55:43.339253-05:00         21.0  0.250000
# 10    2019-11-28 09:16:43.612971-05:00         78.0  0.300000
# 11 2019-11-28 09:18:59.634557579-05:00         25.0  0.250000

# %%
train_df[[
    'index', 'subwayline','station_char_o', 'stationid_o', 'traindirection', 'trip', 'trainid', 'estimated_arrival_o',
    'station_char_d',  'stationid_d', 'estimated_arrival_d', 'cost'
]].to_csv('processed_subway/train-arrival_2019-11-28_AM.csv', index = False)

# %%
train_df[train_df['subw'[['station_char_o', 'stationid_o']].drop_duplicates().sort_values(by = 'stationid_o').iloc[100:150]
# Out:
#     station_char_o  stationid_o
# 11            BSP1           47
# 7             SPA1           47
# 53            SPA2           47
# 75            BSP2           47
# 80            SGU2           48
# 111           SGU1           48
# 106           SGL1           48
# 14            SGL2           48
# 14            BAU2           49
# 46            BAU1           49
# 75            BLO1           50
# 156           YNG2           50
# 102           BLO2           50
# 106           YNG1           50
# 48            SHE1           51
# 12            SHE2           51
# 49            CFK1           52
# 11            CFK2           52
# 10            BRD2           53
# 50            BRD1           53
# 9             CHE2           54
# 51            CHE1           54
# 8             PAP2           55
# 52            PAP1           55
# 53            DON1           56
# 7             DON2           56
# 6             GWD2           57
# 54            GWD1           57
# 5             COX2           58
# 55            COX1           58
# 56            WDB1           59
# 4             WDB2           59
# 3             MST2           60
# 57            MST1           60
# 58            VPK1           61
# 2             VPK2           61
# 0             WAR1           62
# 1             WAR2           62
# 91            KEN1           63
# 60            KEN2           63
# 7             YIE2           64
# 82            SHP1           64
# 14            SHP2           64
# 67            YIE1           64
# 0             BYV1           65
# 15            BYV2           65
# 1             BSS1           66
# 6             BSS2           66
# 2             LES1           67
# 5             LES2           67
