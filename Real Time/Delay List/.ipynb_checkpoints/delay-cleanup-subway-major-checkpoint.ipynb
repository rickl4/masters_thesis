# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
df = pd.read_csv('subway_delay-winter-2019.csv')

# %%
df
# Out:
#      Report Date  Route   Time     Day                Location Incident  \
# 0     2019-11-01     BD  15:28  Friday          WARDEN STATION     SUDP
# 1     2019-11-01     YU  21:49  Friday           UNION STATION      MUI
# 2     2019-11-01     YU  00:00  Friday       GLENCAIRN STATION      MUI
# 3     2019-11-01     BD  07:35  Friday       OSSINGTON STATION     SUDP
# 4     2019-11-01     BD  17:53  Friday        YONGE BD STATION     MUDD
# ...          ...    ...    ...     ...                     ...      ...
# 4371  2020-01-31     BD  21:55  Friday          WARDEN STATION    TUMVS
# 4372  2020-01-31  YU/BD  22:00  Friday  YONGE-UNIVERSITY AND B      MUO
# 4373  2020-01-31     YU  22:26  Friday   SHEPPARD WEST STATION    PUMEL
# 4374  2020-01-31     YU  22:28  Friday        ST CLAIR STATION      MUI
# 4375  2020-01-31     YU  23:13  Friday           QUEEN STATION    MUIRS
#
#       Delay  Gap Directoin  Vehicle
# 0        19   22         E     5209
# 1        16   19         N     6001
# 2        15   20         S     5526
# 3        10   12         E     5209
# 4        10   12         W     5091
# ...     ...  ...       ...      ...
# 4371      0    0         W     5100
# 4372      0    0       NaN        0
# 4373      0    0       NaN        0
# 4374      0    0         N     5636
# 4375      0    0       NaN        0
#
# [4376 rows x 10 columns]

# %%
df = df[df['Delay'] > 14]
# Out:
#      Report Date Route   Time        Day                Location Incident  \
# 0     2019-11-01    BD  15:28     Friday          WARDEN STATION     SUDP
# 1     2019-11-01    YU  21:49     Friday           UNION STATION      MUI
# 2     2019-11-01    YU  00:00     Friday       GLENCAIRN STATION      MUI
# 57    2019-11-02    BD  19:09   Saturday           KEELE STATION     SUSP
# 58    2019-11-02   SRT  09:59   Saturday  SCARBOROUGH RAPID TRAN      PRS
# ...          ...   ...    ...        ...                     ...      ...
# 4011  2020-01-24   SRT  06:10     Friday  SCARBOROUGH CTR STATIO     ERTC
# 4012  2020-01-24    BD  11:08     Friday      KENNEDY BD STATION    PUSSW
# 4062  2020-01-25    BD  11:32   Saturday       RUNNYMEDE STATION    MUPR1
# 4207  2020-01-29    YU  08:01  Wednesday  PIONEER VILLAGE STATIO      MUI
# 4259  2020-01-30    YU  17:43   Thursday    QUEEN'S PARK STATION    MUPR1
#
#       Delay  Gap Directoin  Vehicle
# 0        19   22         E     5209
# 1        16   19         N     6001
# 2        15   20         S     5526
# 57       67   72         E     5349
# 58       18   23       NaN        0
# ...     ...  ...       ...      ...
# 4011     36   41         S     3016
# 4012     33   36         W     5229
# 4062    131  135         W     5309
# 4207     30   32         S     5411
# 4259    112  114         N     6061
#
# [101 rows x 10 columns]

# %%
df['datetime'] = df['Report Date'] + ' ' + df['Time']

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4376 entries, 0 to 4375
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Report Date  4376 non-null   object
#  1   Route        4366 non-null   object
#  2   Time         4376 non-null   object
#  3   Day          4376 non-null   object
#  4   Location     4376 non-null   object
#  5   Incident     4376 non-null   object
#  6   Delay        4376 non-null   int64
#  7   Gap          4376 non-null   int64
#  8   Directoin    3318 non-null   object
#  9   Vehicle      4376 non-null   int64
#  10  datetime     4376 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 376.2+ KB

# %%
df = df[(df['datetime'] >'2019-11-27') & (df['datetime'] < '2020-01-05')]

# %%
df['dow'] = df['datetime'].dt.weekday
# Out:
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_14813/556086759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dow'] = df['datetime'].dt.weekday

# %%
df['hour'] = df['datetime'].dt.hour
# Out:
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_14813/1798199548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df['datetime'].dt.hour

# %%
df['minute'] = df['datetime'].dt.minute
# Out:
# /var/folders/zw/x46df3ms6r5391lyb_y98z600000gn/T/ipykernel_14813/2789465128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df['datetime'].dt.minute

# %%
df[df['datetime'].dt.date.astype(str) == '2019-12-02'].sort_values(by = 'Delay', ascending = False)
# Out:
#      Report Date Route   Time     Day                Location Incident  Delay  \
# 1493  2019-12-02    BD  06:59  Monday     DUNDAS WEST STATION    MUPLB    176
# 1494  2019-12-02    BD  09:31  Monday         CHESTER STATION    MUPLB     21
# 1495  2019-12-02    BD  22:48  Monday      SHERBOURNE STATION     SUAP     16
# 1496  2019-12-02    BD  00:13  Monday  YORK UNIVERSITY STATIO    MUATC     13
# 1497  2019-12-02    BD  08:35  Monday         CHESTER STATION    MUPLB     11
# ...          ...   ...    ...     ...                     ...      ...    ...
# 1539  2019-12-02    YU  07:54  Monday     SPADINA YUS STATION    MUATC      0
# 1540  2019-12-02    YU  08:59  Monday        YORKDALE STATION     SUAP      0
# 1541  2019-12-02    YU  09:00  Monday        LAWRENCE STATION    MUPAA      0
# 1542  2019-12-02    BD  09:09  Monday        YONGE BD STATION     MUIR      0
# 1563  2019-12-02    BD  23:37  Monday       BROADVIEW STATION      SUO      0
#
#       Gap Directoin  Vehicle            datetime  dow  hour  minute
# 1493  180         W     5030 2019-12-02 06:59:00    0     6      59
# 1494   23         W     5298 2019-12-02 09:31:00    0     9      31
# 1495   21         E     5207 2019-12-02 22:48:00    0    22      48
# 1496   17         N     6056 2019-12-02 00:13:00    0     0      13
# 1497   13         W     5258 2019-12-02 08:35:00    0     8      35
# ...   ...       ...      ...                 ...  ...   ...     ...
# 1539    0         N     5391 2019-12-02 07:54:00    0     7      54
# 1540    0         S     5856 2019-12-02 08:59:00    0     8      59
# 1541    0         S     5976 2019-12-02 09:00:00    0     9       0
# 1542    0         W     5212 2019-12-02 09:09:00    0     9       9
# 1563    0         E     5077 2019-12-02 23:37:00    0    23      37
#
# [71 rows x 14 columns]

# %%
df[df['Incident'] == 'General Delay']
# Out:
# Empty DataFrame
# Columns: [Report Date, Route, Time, Day, Location, Incident, Delay, Gap, Directoin, Vehicle, datetime, dow, hour, minute]
# Index: []

# %%
df[df['Gap']/df['Delay'] == 2]
# Out:
#      Report Date Route   Time        Day            Location Incident  Delay  \
# 1263  2019-11-27   SRT  14:43  Wednesday     MCCOWAN STATION      MRO      5
# 1264  2019-11-27   SHP  16:09  Wednesday     BAYVIEW STATION      TUS      5
# 1265  2019-11-27   SHP  16:35  Wednesday   DON MILLS STATION      TUS      5
# 1276  2019-11-27    BD  12:06  Wednesday  KENNEDY BD STATION     EUBK      3
# 1277  2019-11-27    YU  13:30  Wednesday      DUPONT STATION      TUO      3
# ...          ...   ...    ...        ...                 ...      ...    ...
# 3148  2020-01-04    BD  19:49   Saturday     KIPLING STATION      MUI      5
.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_str'] = df['datetime'].dt.date.astype(str)

# %%
df.groupby(['date_str', 'Route']).count().sort_values(by = 'Report Date', ascending = False)
# Out:
#                   Report Date  Time  Day  Location  Incident  Delay  Gap  \
# date_str   Route
# 2019-12-07 YU              52    52   52        52        52     52   52
# 2019-11-27 YU              46    46   46        46        46     46   46
# 2019-12-20 YU              38    38   38        38        38     38   38
# 2019-12-18 YU              35    35   35        35        35     35   35
# 2019-12-24 YU              35    35   35        35        35     35   35
# ...                       ...   ...  ...       ...       ...    ...  ...
# 2019-11-30 SRT              1     1    1         1         1      1    1
# 2019-12-28 SHP              1     1    1         1         1      1    1
#            SRT              1     1    1         1         1      1    1
# 2019-12-06 SRT              1     1    1         1         1      1    1
# 2020-01-04 YU/BD            1     1    1         1         1      1    1
#
#                   Directoin  Vehicle  datetime  dow  hour  minute
# date_str   Route
# 2019-12-07 YU            41       52        52   52    52      52
# 2019-11-27 YU            40       46        46   46    46      46
# 2019-12-20 YU            27       38        38   38    38      38
# 2019-12-18 YU            30       35        35   35    35      35
# 2019-12-24 YU            25       35        35   35    35      35
# ...                     ...      ...       ...  ...   ...     ...
# 2019-11-30 SRT            0        1         1    1     1       1
# 2019-12-28 SHP            1        1         1    1     1       1
#            SRT            1        1         1    1     1       1
# 2019-12-06 SRT            0        1         1    1     1       1
# 2020-01-04 YU/BD          0        1         1    1     1       1
#
# [182 rows x 13 columns]

# %%
df[(df['Route'] == 'YU') & (df['date_str'] == '2019-12-10')]
# Out:
#      Report Date Route   Time      Day                Location Incident  \
# 1927  2019-12-10    YU  01:29  Tuesday   SHEPPARD WEST STATION     SUAE
# 1928  2019-12-10    YU  13:16  Tuesday        ST CLAIR STATION      MUI
# 1929  2019-12-10    YU  01:12  Tuesday        SHEPPARD STATION     SUDP
# 1931  2019-12-10    YU  16:29  Tuesday      ST PATRICK STATION     MUIR
# 1932  2019-12-10    YU  19:39  Tuesday           QUEEN STATION     MUDD
# 1933  2019-12-10    YU  19:58  Tuesday   EGLINTON WEST STATION    SUROB
# 1937  2019-12-10    YU  06:44  Tuesday     DAVISVILLE BUILD UP    TUNIP
# 1938  2019-12-10    YU  12:02  Tuesday      DAVISVILLE STATION     SUAP
# 1939  2019-12-10    YU  14:08  Tuesday       WELLESLEY STATION     SUDP
# 1942  2019-12-10    YU  05:52  Tuesday   ST GEORGE YUS STATION    MUATC
# 1947  2019-12-10    YU  01:16  Tuesday        ROSEDALE STATION     SUDP
# 1948  2019-12-10    YU  01:20  Tuesday           BLOOR STATION    MUPAA
# 1950  2019-12-10    YU  04:09  Tuesday         COLLEGE STATION     PUMO
# 1951  2019-12-10    YU  06:04  Tuesday      VAUGHAN MC STATION    MUATC
# 1952  2019-12-10    YU  06:11  Tuesday      VAUGHAN MC STATION    TUNIP
# 1954  2019-12-10    YU  06:37  Tuesday        EGLINTON STATION    TUNIP
# 1955  2019-12-10    YU  06:43  Tuesday      VAUGHAN MC STATION     MUIE
# 1956  2019-12-10    YU  07:50  Tuesday        LAWRENCE STATION     EUDO
# 1957  2019-12-10    YU  08:37  Tuesday         COLLEGE STATION     MUSC
# 1958  2019-12-10    YU  08:46  Tuesday    QUEEN'S PARK STATION    MUIRS
# 1970      0    0       NaN        0 2019-12-10 17:18:00    1    17      18
# 1971      0    0         S     6036 2019-12-10 18:13:00    1    18      13
# 1976      0    0         S     6036 2019-12-10 21:00:00    1    21       0
# 1980      0    0         S     5646 2019-12-10 22:41:00    1    22      41
# 1981      0    0       NaN        0 2019-12-10 22:52:00    1    22      52
#
#         date_str
# 1927  2019-12-10
# 1928  2019-12-10
# 1929  2019-12-10
# 1931  2019-12-10
# 1932  2019-12-10
# 1933  2019-12-10
# 1937  2019-12-10
# 1938  2019-12-10
# 1939  2019-12-10
# 1942  2019-12-10
# 1947  2019-12-10
# 1948  2019-12-10
# 1950  2019-12-10
# 1951  2019-12-10
# 1952  2019-12-10
# 1954  2019-12-10
# 1955  2019-12-10
# 1956  2019-12-10
# 1957  2019-12-10
# 1958  2019-12-10
# 1959  2019-12-10
# 1960  2019-12-10
# 1961  2019-12-10
# 1962  2019-12-10
# 1964  2019-12-10
# 1966  2019-12-10
# 1967  2019-12-10
# 1968  2019-12-10
# 1969  2019-12-10
# 1970  2019-12-10
# 1971  2019-12-10
# 1976  2019-12-10
# 1980  2019-12-10
# 1981  2019-12-10

# %%
clean_list = []

for index, row in df.iterrows():
        
    new_hour = row['hour']
    delay = row['Delay']
    minute = row['minute']
    new_date = row['datetime'].date()
    new_dow = new_dow = new_date.weekday()
    clean_list.append([row['datetime'].date(), row['dow'], row['hour'], row['Route']])
    
    if delay + minute > 60:

            
        for i in range(int((delay + minute)/60)):
            new_hour = new_hour + 1
            if new_hour > 23:
                new_hour = new_hour - 24
                new_date = row['datetime'].date() + datetime.timedelta(days=1)
                new_dow = new_date.weekday()

            clean_list.append([new_date, new_dow, new_hour, row['Route']])       

    else:
        pass

# %%
cleaned = pd.DataFrame.from_records(clean_list, columns = ['date', 'dow', 'hour', 'route'])
cleaned
# Out:
#             date  dow  hour  route
# 0     2019-11-27    2    19     YU
# 1     2019-11-27    2    16     BD
# 2     2019-11-27    2     0     YU
# 3     2019-11-27    2    16     BD
# 4     2019-11-27    2    23     YU
# ...          ...  ...   ...    ...
# 1981  2020-01-04    5    19     YU
# 1982  2020-01-04    5    20    SHP
# 1983  2020-01-04    5    21     YU
# 1984  2020-01-04    5    22  YU/BD
# 1985  2020-01-04    5    23     BD
#
# [1986 rows x 4 columns]

# %%
cleaned = cleaned[~cleaned['date'].astype(str).isin(['2019-12-24', '2019-12-25', '2019-12-26', '2019-12-31', '2020-01-01'])].copy()

# %%
cleaned['period'] = None

# %%
cleaned['period'] = np.where((cleaned['dow'] < 5) & (cleaned['hour'].isin([7,8,9])), 'AM', cleaned['period'])
cleaned['period'] = np.where((cleaned['dow'] < 5) & (cleaned['hour'].isin([4,5,6])), 'EM', cleaned['period'])
cleaned['period'] = np.where((cleaned['dow'] < 5) & (cleaned['hour'].isin([11,12,13])), 'MD', cleaned['period'])
cleaned['period'] = np.where((cleaned['dow'] < 5) & (cleaned['hour'].isin([17,18,19])), 'PM', cleaned['period'])
cleaned['period'] = np.where((cleaned['dow'] < 5) & (cleaned['hour'].isin([20,21,22])), 'EV', cleaned['period'])

# %%
cleaned = cleaned[(~cleaned['period'].isna()) ].reset_index(drop = True)
cleaned
# Out:
#            date  dow  hour  route period
# 0    2019-11-27    2    19     YU     PM
# 1    2019-11-27    2     7     YU     AM
# 2    2019-11-27    2     9     YU     AM
# 3    2019-11-27    2     8     YU     AM
# 4    2019-11-27    2     9     YU     AM
# ..          ...  ...   ...    ...    ...
# 899  2020-01-03    4    18    SRT     PM
# 900  2020-01-03    4    19     YU     PM
# 901  2020-01-03    4    21     BD     EV
# 902  2020-01-03    4    22  YU/BD     EV
# 903  2020-01-03    4    22     YU     EV
#
# [904 rows x 5 columns]

# %%
summary = cleaned.groupby(['date', 'period']).count()[['route']].reset_index().rename(columns = {'route':'incidents'})

# %%
len(summary[summary['period'] == 'AM'])
# Out:
# 23

# %%
summary[summary['period'] == 'AM'].sort_values(by = 'incidents', ascending = False)
# Out:
#            date period  incidents
# 0    2019-11-27     AM         23
# 15   2019-12-02     AM         19
# 65   2019-12-16     AM         18
# 75   2019-12-18     AM         16
# 55   2019-12-12     AM         13
# 60   2019-12-13     AM         12
# 85   2019-12-20     AM         12
# 110  2020-01-03     AM         10
# 30   2019-12-05     AM         10
# 80   2019-12-19     AM          9
# 35   2019-12-06     AM          9
# 40   2019-12-09     AM          9
# 50   2019-12-11     AM          9
# 5    2019-11-28     AM          9
# 90   2019-12-23     AM          9
# 100  2019-12-30     AM          8
# 25   2019-12-04     AM          8
# 10   2019-11-29     AM          8
# 20   2019-12-03     AM          7
# 45   2019-12-10     AM          7
# 70   2019-12-17     AM          7
# 105  2020-01-02     AM          5
# 95   2019-12-27     AM          4

# %%
summary[summary['period'] == 'PM'].sort_values(by = 'incidents', ascending = False)
# Out:
#            date period  incidents
# 89   2019-12-20     PM         15
# 79   2019-12-18     PM         14
# 9    2019-11-28     PM         14
# 4    2019-11-27     PM         13
# 44   2019-12-09     PM         12
# 24   2019-12-03     PM         11
# 49   2019-12-10     PM         10
# 34   2019-12-05     PM         10
# 29   2019-12-04     PM          9
# 64   2019-12-13     PM          9
# 19   2019-12-02     PM          9
# 99   2019-12-27     PM          8
# 54   2019-12-11     PM          8
# 104  2019-12-30     PM          8
# 69   2019-12-16     PM          7
# 84   2019-12-19     PM          7
# 14   2019-11-29     PM          7
# 94   2019-12-23     PM          7
# 109  2020-01-02     PM          6
# 59   2019-12-12     PM          6
# 39   2019-12-06     PM          6
# 114  2020-01-03     PM          6
# 74   2019-12-17     PM          5

# %%
summary[summary['period'] == 'MD'].sort_values(by = 'incidents', ascending = False)
# Out:
#            date period  incidents
# 78   2019-12-18     MD         13
# 98   2019-12-27     MD         12
# 73   2019-12-17     MD         10
# 48   2019-12-10     MD          9
# 108  2020-01-02     MD          9
# 28   2019-12-04     MD          9
# 33   2019-12-05     MD          9
# 43   2019-12-09     MD          9
# 93   2019-12-23     MD          8
# 83   2019-12-19     MD          7
# 63   2019-12-13     MD          7
# 58   2019-12-12     MD          7
# 23   2019-12-03     MD          7
# 88   2019-12-20     MD          6
# 103  2019-12-30     MD          5
# 68   2019-12-16     MD          5
# 38   2019-12-06     MD          5
# 13   2019-11-29     MD          5
# 3    2019-11-27     MD          4
# 18   2019-12-02     MD          4
# 113  2020-01-03     MD          4
# 53   2019-12-11     MD          3
# 8    2019-11-28     MD          1

# %%
summary[summary['period'] == 'EV'].sort_values(by = 'incidents', ascending = False)
# Out:
#            date period  incidents
# 87   2019-12-20     EV         15
# 22   2019-12-03     EV          9
# 92   2019-12-23     EV          9
# 82   2019-12-19     EV          9
# 47   2019-12-10     EV          9
# 102  2019-12-30     EV          8
# 2    2019-11-27     EV          7
# 7    2019-11-28     EV          7
# 107  2020-01-02     EV          7
# 62   2019-12-13     EV          7
# 57   2019-12-12     EV          7
# 52   2019-12-11     EV          7
# 37   2019-12-06     EV          7
# 32   2019-12-05     EV          7
# 12   2019-11-29     EV          7
# 72   2019-12-17     EV          6
# 17   2019-12-02     EV          6
# 112  2020-01-03     EV          6
# 42   2019-12-09     EV          5
# 27   2019-12-04     EV          5
# 97   2019-12-27     EV          5
# 77   2019-12-18     EV          4
# 67   2019-12-16     EV          3

# %%
summary[summary['period'] == 'EM'].sort_values(by = 'incidents', ascending = False)
# Out:
#            date period  incidents
# 16   2019-12-02     EM         17
# 101  2019-12-30     EM         11
# 26   2019-12-04     EM         10
# 96   2019-12-27     EM          8
# 46   2019-12-10     EM          8
# 86   2019-12-20     EM          7
# 41   2019-12-09     EM          7
# 36   2019-12-06     EM          6
# 81   2019-12-19     EM          6
# 76   2019-12-18     EM          6
# 1    2019-11-27     EM          5
# 71   2019-12-17     EM          5
# 111  2020-01-03     EM          5
# 6    2019-11-28     EM          5
# 51   2019-12-11     EM          4
# 31   2019-12-05     EM          4
# 21   2019-12-03     EM          4
# 11   2019-11-29     EM          4
# 106  2020-01-02     EM          4
# 91   2019-12-23     EM          3
# 66   2019-12-16     EM          2
# 61   2019-12-13     EM          1
# 56   2019-12-12     EM          1

# %%
plt.rcParams['figure.dpi'] = 300

# %%
fig, ax = plt.subplots(5)

i = 0
y_str = 0.86

period_list = ['EM','AM','MD','PM','EV']

for period in period_list:
    
    df_sub = summary[summary['period'] == period]
    
    ax[i].bar(df_sub['date'], df_sub['incidents'])
    
    ax[i].set_xlim([datetime.date(2019,11,26), datetime.date(2020,1,4)])
    ax[i].set_ylim([0,25])
    
    ax[i].set_xticks([datetime.date(2019,11,25),
                     datetime.date(2019,12,2),
                     datetime.date(2019,12,9),
                     datetime.date(2019,12,16),
                     datetime.date(2019,12,23),
                     datetime.date(2019,12,30)])


    if i in [0,1,2,3]:
        ax[i].set_xticklabels('')
    else:
        ax[i].xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
    
        
    fig.text(s = period + ' Period', x = 0.78, y = y_str)

    ax[i].grid(color = 'xkcd:light grey')
    
    
    
    i = i + 1
    y_str = y_str - 0.157
    
fig.add_subplot(111, frameon=False)


plt.xlabel('Date')
plt.ylabel('Number of Incidents')
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
plt.grid(False)
plt.title('Subway Delays', ha = 'left', x = 0)

fig.set_size_inches(6.5,8.5)

plt.savefig('subway-delay-count-major.png', dpi = 300, bbox_inches = "tight")

# %%
summary.to_csv('subway_delay_summary-major.csv', index = False)
cleaned.to_csv('subway_cleaned-major.csv', index = False)
