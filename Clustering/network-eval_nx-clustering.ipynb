# %%
import networkx as nx
import pandas as pd
import numpy as np
from scipy import stats
import statistics

# %%
simplify_dir = '/Volumes/Data2/RST/notebook/GTFS/TTC_2016-10-03/GIS Simplify/'
gtfs_dir = '/Volumes/Data2/RST/notebook/GTFS/TTC_2016-10-03/'

# %%
ward_int = pd.read_csv('/Volumes/Data2/RST/notebook/GIS/int_wards.csv')

# %%
G = nx.read_gexf('/Volumes/Data2/RST/notebook/networks/AM-RM-16-singleDi.gexf')

# %%
df_list = []
cluster_list = []
for period in ['EM', 'AM', 'MD', 'PM', 'EV']:
    G = nx.read_gexf('/Volumes/Data2/RST/notebook/networks/' + period + '-RM-16-singleDi.gexf')
    graph_data = pd.read_csv('/Volumes/Data2/RST/notebook/networks/' + period + '-RM-16-singleDi.csv')

    clustering = nx.algorithms.cluster.clustering(G, weight = 'freq')

    cluster_df = pd.DataFrame([[key, value] for key, value in clustering.items()], columns = ['INT_ID', 'cc'])

    cluster_df['INT_ID'] = cluster_df['INT_ID'].astype(int)

    cluster_df = cluster_df.merge(ward_int)

    neighbor_degree = []
    for node in list(G.nodes()):
        
        # no neighbours
        if len(list(G.neighbors(node))) == 0:
            neighbor_degree.append([int(node),0,0])
            
        # when there are neighbours beyond neighbours of the same route
        elif (G.degree(node) - 4) > 0:
            neighbor_degree.append([int(node), 
                                    statistics.mean([G.degree(n, weight = 'scaled_freq') for n in G.neighbors(node)]),
                                    G.degree(node, weight = 'scaled_freq')])
        else:
            neighbor_degree.append([int(node), 
                                    statistics.mean([G.degree(n, weight = 'scaled_freq') for n in G.neighbors(node)]),
                                   0])

    cluster_df = cluster_df.merge(pd.DataFrame.from_records(neighbor_degree, columns = ['INT_ID', 'neighbor_avg',
                                                                                       'transfer_avg']))
    cluster_int = cluster_df.copy()
    
    cluster_int['period'] = period
    
    cluster_list.append(cluster_int)
    
    avg_cluster = []
    for i  in range(1, 26, 1):
        int_list = list(cluster_df[cluster_df['AREA_SHORT_CODE']==i]['INT_ID'].astype(str))
        G_ward = G.subgraph(int_list).copy()
        avg_cluster.append([i, 2 * G_ward.number_of_edges()/(G_ward.number_of_nodes() ** 2)])

    cluster_ward = cluster_df.groupby('AREA_SHORT_CODE').mean()[['cc', 'neighbor_avg', 'transfer_avg']].reset_index().copy()
    cluster_ward = cluster_ward.merge(pd.DataFrame.from_records(avg_cluster, columns = ['AREA_SHORT_CODE', 'mean_random']))

    cluster_ward['cc_normalized'] = cluster_ward['cc']/cluster_ward['mean_random']

    cluster_ward = cluster_ward.merge(ward_int[['AREA_SHORT_CODE', 'AREA_NAME']].drop_duplicates())

    cluster_ward['period'] = period
    
    df_list.append(cluster_ward)

# %%
pd.concat(cluster_list).to_csv('cluster_int.csv', index = False)

# %%
cluster = pd.concat(df_list)
cluster
# Out:
#     AREA_SHORT_CODE        cc  neighbor_avg  transfer_avg  mean_random  \
# 0                 1  0.000062      0.080221      0.018078     0.026996
# 1                 2  0.001553      0.073643      0.012987     0.033466
# 2                 3  0.000782      0.123061      0.016829     0.031901
# 3                 4  0.001906      0.156527      0.044794     0.068371
# 4                 5  0.000914      0.099830      0.021599     0.035918
# ..              ...       ...           ...           ...          ...
# 20               21  0.006500      0.456060      0.163659     0.022407
# 21               22  0.008930      0.473257      0.184480     0.034787
# 22               23  0.004497      0.406297      0.159880     0.026614
# 23               24  0.009587      0.540616      0.175776     0.035690
# 24               25  0.004959      0.318527      0.087168     0.023637
#
#     cc_normalized               AREA_NAME period
# 0        0.002291         Etobicoke North     EM
# 1        0.046420        Etobicoke Centre     EM
# 2        0.024501     Etobicoke-Lakeshore     EM
# 3        0.027871      Parkdale-High Park     EM
# 4        0.025439       York South-Weston     EM
# ..            ...                     ...    ...
# 20       0.290090      Scarborough Centre     EV
# 21       0.256704   Scarborough-Agincourt     EV
# 22       0.168988       Scarborough North     EV
# 23       0.268618   Scarborough-Guildwood     EV
# 24       0.209797  Scarborough-Rouge Park     EV
#
# [125 rows x 8 columns]

# %%
cluster = cluster.rename(columns = {'AREA_SHORT_CODE':'ward', 'AREA_NAME':'ward_name'})
cluster
# Out:
#     ward        cc  neighbor_avg  transfer_avg  mean_random  cc_normalized  \
# 0      1  0.000062      0.080221      0.018078     0.026996       0.002291
# 1      2  0.001553      0.073643      0.012987     0.033466       0.046420
# 2      3  0.000782      0.123061      0.016829     0.031901       0.024501
# 3      4  0.001906      0.156527      0.044794     0.068371       0.027871
# 4      5  0.000914      0.099830      0.021599     0.035918       0.025439
# ..   ...       ...           ...           ...          ...            ...
# 20    21  0.006500      0.456060      0.163659     0.022407       0.290090
# 21    22  0.008930      0.473257      0.184480     0.034787       0.256704
# 22    23  0.004497      0.406297      0.159880     0.026614       0.168988
# 23    24  0.009587      0.540616      0.175776     0.035690       0.268618
# 24    25  0.004959      0.318527      0.087168     0.023637       0.209797
#
#                  ward_name period
# 0          Etobicoke North     EM
# 1         Etobicoke Centre     EM
# 2      Etobicoke-Lakeshore     EM
# 3       Parkdale-High Park     EM
# 4        York South-Weston     EM
# ..                     ...    ...
# 20      Scarborough Centre     EV
# 21   Scarborough-Agincourt     EV
# 22       Scarborough North     EV
# 23   Scarborough-Guildwood     EV
# 24  Scarborough-Rouge Park     EV
#
# [125 rows x 8 columns]

# %%
cluster.to_csv('cluster.csv', index = False)

# %%
cluster[cluster['period'] == 'AM'].sort_values(by = 'cc_normalized', ascending = False)
# Out:
#     ward        cc  neighbor_avg  transfer_avg  mean_random  cc_normalized  \
# 14    15  0.011911      0.658062      0.216573     0.022216       0.536146
# 5      6  0.010095      0.690109      0.282617     0.021710       0.464987
# 11    12  0.012560      0.843914      0.349942     0.032908       0.381657
# 23    24  0.013905      0.867824      0.306936     0.037051       0.375302
# 21    22  0.013240      0.755359      0.305629     0.035359       0.374436
# 20    21  0.008105      0.761893      0.281808     0.023275       0.348215
# 16    17  0.011563      0.737736      0.275409     0.034417       0.335955
# 9     10  0.012876      1.124662      0.495307     0.040311       0.319419
# 2      3  0.005640      0.513436      0.161248     0.018098       0.311608
# 24    25  0.006875      0.513782      0.154900     0.022186       0.309867
# 19    20  0.005970      0.654531      0.253117     0.020025       0.298151
# 22    23  0.006972      0.595873      0.242003     0.025594       0.272424
# 15    16  0.007724      0.705218      0.296891     0.030640       0.252097
# 13    14  0.006594      0.799614      0.293940     0.029610       0.222707
# 12    13  0.009503      1.051516      0.479504     0.046339       0.205068
# 3      4  0.007250      0.702138      0.286741     0.035375       0.204953
# 4      5  0.004839      0.697328      0.234195     0.024772       0.195341
# 6      7  0.004348      0.601398      0.236293     0.023706       0.183398
# 10    11  0.005672      0.808257      0.389154     0.034844       0.162769
# 17    18  0.004426      0.619250      0.207988     0.029616       0.149458
# 18    19  0.003255      0.543906      0.183017     0.025072       0.129827
# 7      8  0.003068      0.663332      0.242232     0.023748       0.129209
# 0      1  0.002469      0.478778      0.170101     0.020294       0.121671
# 8      9  0.003567      0.854036      0.331740     0.033852       0.105369
# 1      2  0.001934      0.493017      0.144545     0.021894       0.088318
#
#                    ward_name period
# 14           Don Valley West     AM
# 5                York Centre     AM
# 11        Toronto-St. Paul's     AM
# 23     Scarborough-Guildwood     AM
# 21     Scarborough-Agincourt     AM
# 20        Scarborough Centre     AM
# 16          Don Valley North     AM
# 9          Spadina-Fort York     AM
# 2        Etobicoke-Lakeshore     AM
# 24    Scarborough-Rouge Park     AM
# 19     Scarborough Southwest     AM
# 22         Scarborough North     AM
# 15           Don Valley East     AM
# 13          Toronto-Danforth     AM
# 12            Toronto Centre     AM
# 3         Parkdale-High Park     AM
# 4          York South-Weston     AM
# 6   Humber River-Black Creek     AM
# 10       University-Rosedale     AM
# 17                Willowdale     AM
# 18         Beaches-East York     AM
# 7          Eglinton-Lawrence     AM
# 0            Etobicoke North     AM
# 8                  Davenport     AM
# 1           Etobicoke Centre     AM

# %%
cluster[cluster['period'] == 'AM'].sort_values(by = 'cc', ascending = False)
# Out:
#     ward        cc  neighbor_avg  transfer_avg  mean_random  cc_normalized  \
# 23    24  0.013905      0.867824      0.306936     0.037051       0.375302
# 21    22  0.013240      0.755359      0.305629     0.035359       0.374436
# 9     10  0.012876      1.124662      0.495307     0.040311       0.319419
# 11    12  0.012560      0.843914      0.349942     0.032908       0.381657
# 14    15  0.011911      0.658062      0.216573     0.022216       0.536146
# 16    17  0.011563      0.737736      0.275409     0.034417       0.335955
# 5      6  0.010095      0.690109      0.282617     0.021710       0.464987
# 12    13  0.009503      1.051516      0.479504     0.046339       0.205068
# 20    21  0.008105      0.761893      0.281808     0.023275       0.348215
# 15    16  0.007724      0.705218      0.296891     0.030640       0.252097
# 3      4  0.007250      0.702138      0.286741     0.035375       0.204953
# 22    23  0.006972      0.595873      0.242003     0.025594       0.272424
# 24    25  0.006875      0.513782      0.154900     0.022186       0.309867
# 13    14  0.006594      0.799614      0.293940     0.029610       0.222707
# 19    20  0.005970      0.654531      0.253117     0.020025       0.298151
# 10    11  0.005672      0.808257      0.389154     0.034844       0.162769
# 2      3  0.005640      0.513436      0.161248     0.018098       0.311608
# 4      5  0.004839      0.697328      0.234195     0.024772       0.195341
# 17    18  0.004426      0.619250      0.207988     0.029616       0.149458
# 6      7  0.004348      0.601398      0.236293     0.023706       0.183398
# 8      9  0.003567      0.854036      0.331740     0.033852       0.105369
# 18    19  0.003255      0.543906      0.183017     0.025072       0.129827
# 7      8  0.003068      0.663332      0.242232     0.023748       0.129209
# 0      1  0.002469      0.478778      0.170101     0.020294       0.121671
# 1      2  0.001934      0.493017      0.144545     0.021894       0.088318
#
#                    ward_name period
# 23     Scarborough-Guildwood     AM
# 21     Scarborough-Agincourt     AM
# 9          Spadina-Fort York     AM
# 11        Toronto-St. Paul's     AM
# 14           Don Valley West     AM
# 16          Don Valley North     AM
# 5                York Centre     AM
# 12            Toronto Centre     AM
# 20        Scarborough Centre     AM
# 15           Don Valley East     AM
# 3         Parkdale-High Park     AM
# 22         Scarborough North     AM
# 24    Scarborough-Rouge Park     AM
# 13          Toronto-Danforth     AM
# 19     Scarborough Southwest     AM
# 10       University-Rosedale     AM
# 2        Etobicoke-Lakeshore     AM
# 4          York South-Weston     AM
# 17                Willowdale     AM
# 6   Humber River-Black Creek     AM
# 8                  Davenport     AM
# 18         Beaches-East York     AM
# 7          Eglinton-Lawrence     AM
# 0            Etobicoke North     AM
# 1           Etobicoke Centre     AM

# %%
cluster[cluster['period'] == 'AM'].sort_values(by = 'neighbor_avg', ascending = False)
# Out:
#     ward        cc  neighbor_avg  transfer_avg  mean_random  cc_normalized  \
# 9     10  0.012876      1.124662      0.495307     0.040311       0.319419
# 12    13  0.009503      1.051516      0.479504     0.046339       0.205068
# 23    24  0.013905      0.867824      0.306936     0.037051       0.375302
# 8      9  0.003567      0.854036      0.331740     0.033852       0.105369
# 11    12  0.012560      0.843914      0.349942     0.032908       0.381657
# 10    11  0.005672      0.808257      0.389154     0.034844       0.162769
# 13    14  0.006594      0.799614      0.293940     0.029610       0.222707
# 20    21  0.008105      0.761893      0.281808     0.023275       0.348215
# 21    22  0.013240      0.755359      0.305629     0.035359       0.374436
# 16    17  0.011563      0.737736      0.275409     0.034417       0.335955
# 15    16  0.007724      0.705218      0.296891     0.030640       0.252097
# 3      4  0.007250      0.702138      0.286741     0.035375       0.204953
# 4      5  0.004839      0.697328      0.234195     0.024772       0.195341
# 5      6  0.010095      0.690109      0.282617     0.021710       0.464987
# 7      8  0.003068      0.663332      0.242232     0.023748       0.129209
# 14    15  0.011911      0.658062      0.216573     0.022216       0.536146
# 19    20  0.005970      0.654531      0.253117     0.020025       0.298151
# 17    18  0.004426      0.619250      0.207988     0.029616       0.149458
# 6      7  0.004348      0.601398      0.236293     0.023706       0.183398
# 22    23  0.006972      0.595873      0.242003     0.025594       0.272424
# 18    19  0.003255      0.543906      0.183017     0.025072       0.129827
# 24    25  0.006875      0.513782      0.154900     0.022186       0.309867
# 2      3  0.005640      0.513436      0.161248     0.018098       0.311608
# 1      2  0.001934      0.493017      0.144545     0.021894       0.088318
# 0      1  0.002469      0.478778      0.170101     0.020294       0.121671
#
#                    ward_name period
# 9          Spadina-Fort York     AM
# 12            Toronto Centre     AM
# 23     Scarborough-Guildwood     AM
# 8                  Davenport     AM
# 11        Toronto-St. Paul's     AM
# 10       University-Rosedale     AM
# 13          Toronto-Danforth     AM
# 20        Scarborough Centre     AM
# 21     Scarborough-Agincourt     AM
# 16          Don Valley North     AM
# 15           Don Valley East     AM
# 3         Parkdale-High Park     AM
# 4          York South-Weston     AM
# 5                York Centre     AM
# 7          Eglinton-Lawrence     AM
# 14           Don Valley West     AM
# 19     Scarborough Southwest     AM
# 17                Willowdale     AM
# 6   Humber River-Black Creek     AM
# 22         Scarborough North     AM
# 18         Beaches-East York     AM
# 24    Scarborough-Rouge Park     AM
# 2        Etobicoke-Lakeshore     AM
# 1           Etobicoke Centre     AM
# 0            Etobicoke North     AM

# %%
cluster[cluster['period'] == 'AM'].sort_values(by = 'transfer_avg', ascending = False)
# Out:
#     ward        cc  neighbor_avg  transfer_avg  mean_random  cc_normalized  \
# 9     10  0.012876      1.124662      0.495307     0.040311       0.319419
# 12    13  0.009503      1.051516      0.479504     0.046339       0.205068
# 10    11  0.005672      0.808257      0.389154     0.034844       0.162769
# 11    12  0.012560      0.843914      0.349942     0.032908       0.381657
# 8      9  0.003567      0.854036      0.331740     0.033852       0.105369
# 23    24  0.013905      0.867824      0.306936     0.037051       0.375302
# 21    22  0.013240      0.755359      0.305629     0.035359       0.374436
# 15    16  0.007724      0.705218      0.296891     0.030640       0.252097
# 13    14  0.006594      0.799614      0.293940     0.029610       0.222707
# 3      4  0.007250      0.702138      0.286741     0.035375       0.204953
# 5      6  0.010095      0.690109      0.282617     0.021710       0.464987
# 20    21  0.008105      0.761893      0.281808     0.023275       0.348215
# 16    17  0.011563      0.737736      0.275409     0.034417       0.335955
# 19    20  0.005970      0.654531      0.253117     0.020025       0.298151
# 7      8  0.003068      0.663332      0.242232     0.023748       0.129209
# 22    23  0.006972      0.595873      0.242003     0.025594       0.272424
# 6      7  0.004348      0.601398      0.236293     0.023706       0.183398
# 4      5  0.004839      0.697328      0.234195     0.024772       0.195341
# 14    15  0.011911      0.658062      0.216573     0.022216       0.536146
# 17    18  0.004426      0.619250      0.207988     0.029616       0.149458
# 18    19  0.003255      0.543906      0.183017     0.025072       0.129827
# 0      1  0.002469      0.478778      0.170101     0.020294       0.121671
# 2      3  0.005640      0.513436      0.161248     0.018098       0.311608
# 24    25  0.006875      0.513782      0.154900     0.022186       0.309867
# 1      2  0.001934      0.493017      0.144545     0.021894       0.088318
#
#                    ward_name period
# 9          Spadina-Fort York     AM
# 12            Toronto Centre     AM
# 10       University-Rosedale     AM
# 11        Toronto-St. Paul's     AM
# 8                  Davenport     AM
# 23     Scarborough-Guildwood     AM
# 21     Scarborough-Agincourt     AM
# 15           Don Valley East     AM
# 13          Toronto-Danforth     AM
# 3         Parkdale-High Park     AM
# 5                York Centre     AM
# 20        Scarborough Centre     AM
# 16          Don Valley North     AM
# 19     Scarborough Southwest     AM
# 7          Eglinton-Lawrence     AM
# 22         Scarborough North     AM
# 6   Humber River-Black Creek     AM
# 4          York South-Weston     AM
# 14           Don Valley West     AM
# 17                Willowdale     AM
# 18         Beaches-East York     AM
# 0            Etobicoke North     AM
# 2        Etobicoke-Lakeshore     AM
# 24    Scarborough-Rouge Park     AM
# 1           Etobicoke Centre     AM
