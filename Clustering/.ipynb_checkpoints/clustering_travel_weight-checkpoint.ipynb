# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.dpi'] = 450

# %%
directory = '/Volumes/Data2/RST/notebook/'

# %%
ward_trips = pd.read_csv(directory + 'TTS OD/WARD_TYPE.csv')
ward_trips
# Out:
#        ward_o  ward_d    type       total
# 0           1       1   ab_am    0.552704
# 1           1       1   ab_ev    0.118363
# 2           1       1   ab_md    0.811149
# 3           1       1   ab_pm    0.973774
# 4           1       1   bl_am  168.513442
# ...       ...     ...     ...         ...
# 15777      25      25  rac_pm  399.066513
# 15778      25      25  raw_am  423.889255
# 15779      25      25  raw_ev  206.497937
# 15780      25      25  raw_md  140.284162
# 15781      25      25  raw_pm  496.678038
#
# [15782 rows x 4 columns]

# %%
cluster = pd.read_csv('cluster.csv')

# %%
ward_trips['group'] = ward_trips['type'].str.split('_', expand = True)[0]
ward_trips['period'] = ward_trips['type'].str.split('_', expand = True)[1].str.upper()

# %%
ward_trip_total = ward_trips.groupby(['group', 'period']).sum()[['total']].reset_index()

# %%
origin_con = ward_trips.merge(connectivity[['Ward', 'connectivity', 'period']], left_on = ['ward_o', 'period'], right_on = ['Ward', 'period'])
origin_con['weighted_con'] = origin_con['connectivity'] * origin_con['total']  
origin_con = origin_con.groupby(['group', 'period']).sum()[['weighted_con']].reset_index().sort_values(
    by = ['period', 'weighted_con'], ascending =  False)

# %%
origin_con = origin_con.merge(ward_trip_total)
origin_con['avg_con'] = origin_con['weighted_con']/origin_con['total']
origin_con.sort_values(by = ['period', 'avg_con'], ascending =  False)
# Out:
#    group period  weighted_con          total    avg_con
# 7     ab     PM  3.112485e+04     365.565840  85.141568
# 5    imm     PM  1.237098e+06   14543.038559  85.064617
# 0    raw     PM  1.731121e+07  204036.850191  84.843545
# 1    rac     PM  8.361040e+06   98678.217618  84.730350
# 2     c0     PM  6.012861e+06   71456.318609  84.147372
# 6    lep     PM  7.469423e+05    8962.136141  83.344226
# 4     bl     PM  1.312059e+06   15936.260026  82.331658
# 3   lico     PM  4.130705e+06   51047.772549  80.918412
# 13   imm     MD  2.486820e+05    4375.865242  56.830363
# 10    c0     MD  1.677826e+06   29899.220918  56.116054
# 11  lico     MD  1.520299e+06   27313.473066  55.661138
# 9    rac     MD  1.683001e+06   30321.167790  55.505812
# 8    raw     MD  3.448987e+06   62582.308176  55.111222
# 15    ab     MD  5.901742e+03     107.510485  54.894575
# 14   lep     MD  1.499769e+05    2810.236280  53.368073
# 12    bl     MD  2.932555e+05    5579.772755  52.556896
# ...

# %%
dest_con = ward_trips.merge(connectivity[['Ward', 'connectivity', 'period']], left_on = ['ward_d', 'period'], right_on = ['Ward', 'period'])
dest_con['weighted_con'] = dest_con['connectivity'] * dest_con['total']  
dest_con = dest_con.groupby(['group', 'period']).sum()[['weighted_con']].reset_index().sort_values(
    by = ['period', 'weighted_con'], ascending =  False)

dest_con = dest_con.merge(ward_trip_total)
dest_con['avg_con'] = dest_con['weighted_con']/dest_con['total']
dest_con.sort_values(by = ['period', 'avg_con'], ascending =  False)
# Out:
#    group period  weighted_con          total    avg_con
# 4    imm     PM  1.198739e+06   14543.038559  82.427022
# 2     c0     PM  5.842203e+06   71456.318609  81.759084
# 1    rac     PM  7.966928e+06   98678.217618  80.736439
# 7     ab     PM  2.913899e+04     365.565840  79.709279
# 0    raw     PM  1.610487e+07  204036.850191  78.931199
# 3   lico     PM  3.996922e+06   51047.772549  78.297675
# 6    lep     PM  6.829253e+05    8962.136141  76.201169
# 5     bl     PM  1.178519e+06   15936.260026  73.952036
# 13   imm     MD  2.441114e+05    4375.865242  55.785847
# 10    c0     MD  1.653492e+06   29899.220918  55.302182
# 9    rac     MD  1.666249e+06   30321.167790  54.953312
# 8    raw     MD  3.412418e+06   62582.308176  54.526888
# 15    ab     MD  5.825507e+03     107.510485  54.185480
# 11  lico     MD  1.471659e+06   27313.473066  53.880346
# 14   lep     MD  1.509473e+05    2810.236280  53.713382
# 12    bl     MD  2.980442e+05    5579.772755  53.415107
# ...

# %%
od_con = ward_trips.merge(connectivity[['Ward', 'connectivity', 'period']], left_on = ['ward_o', 'period'], right_on = ['Ward', 'period'])
od_con = od_con.merge(connectivity[['Ward', 'connectivity', 'period']], left_on = ['ward_d', 'period'], right_on = ['Ward', 'period'])
od_con['od_con'] = (od_con['connectivity_x'] + od_con['connectivity_y'])/2

# %%
od_con['weighted_con'] = od_con['od_con'] * od_con['total']  
od_con = od_con.groupby(['group', 'period']).sum()[['weighted_con']].reset_index().sort_values(
    by = ['period', 'weighted_con'], ascending =  False)

od_con = od_con.merge(ward_trip_total)
od_con['avg_con'] = od_con['weighted_con']/od_con['total']
od_con.sort_values(by = ['period', 'avg_con'], ascending =  False)
# Out:
#    group period  weighted_con          total    avg_con
# 5    imm     PM  1.217919e+06   14543.038559  83.745819
# 2     c0     PM  5.927532e+06   71456.318609  82.953228
# 1    rac     PM  8.163984e+06   98678.217618  82.733394
# 7     ab     PM  3.013192e+04     365.565840  82.425424
# 0    raw     PM  1.670804e+07  204036.850191  81.887372
# 6    lep     PM  7.149338e+05    8962.136141  79.772698
# 3   lico     PM  4.063813e+06   51047.772549  79.608043
# 4     bl     PM  1.245289e+06   15936.260026  78.141847
# 13   imm     MD  2.463967e+05    4375.865242  56.308105
# 10    c0     MD  1.665659e+06   29899.220918  55.709118
# 9    rac     MD  1.674625e+06   30321.167790  55.229562
# 8    raw     MD  3.430703e+06   62582.308176  54.819055
# 11  lico     MD  1.495979e+06   27313.473066  54.770742
# 15    ab     MD  5.863625e+03     107.510485  54.540027
# 14   lep     MD  1.504621e+05    2810.236280  53.540727
# 12    bl     MD  2.956498e+05    5579.772755  52.986002
# ...

# %%
od_con = od_con.sort_values(by = ['period', 'group'], ascending =  False)

# %%
group_df = pd.DataFrame.from_records([['Racialized', 'rac'],
 ['Black', 'bl'],
[ 'Recent\nImmigrants', 'imm'],
 ['Low\nIncome', 'lico'],
[ 'Carless\nHouseholds', 'c0'],
[ 'LEP', 'lep'],
[ 'General\nPopulation', 'raw']], columns = ['Group String', 'group'])

# %%
origin_con = origin_con.merge(group_df)
dest_con = dest_con.merge(group_df)
od_con = od_con.merge(group_df)

# %%
od_con_pivot = od_con.pivot('period', 'Group String', 'avg_con').reindex(['EM','AM','MD','PM','EV'],axis = 0)
od_con_pivot = od_con_pivot.reindex(['Black', 'Low\nIncome', 'LEP', 'General\nPopulation',
                                    'Carless\nHouseholds', 'Racialized', 'Recent\nImmigrants'],axis = 1)

# %%
od_con_pivot
# Out:
# Group String      Black  Low\nIncome        LEP  General\nPopulation  \
# period
# EM             7.082087     8.014624   7.785011             7.658658
# AM            79.794780    82.669377  83.230300            84.649977
# MD            52.986002    54.770742  53.540727            54.819055
# PM            78.141847    79.608043  79.772698            81.887372
# EV            48.021677    50.621129  49.221846            50.237627
#
# Group String  Carless\nHouseholds  Racialized  Recent\nImmigrants
# period
# EM                       7.602958    7.518002            7.751046
# AM                      85.426389   85.712891           87.206855
# MD                      55.709118   55.229562           56.308105
# PM                      82.953228   82.733394           83.745819
# EV                      51.227596   50.672998           51.414948

# %%
od_con_pivot_n = od_con_pivot.div(od_con_pivot.max(axis=1), axis=0)
od_con_pivot_n
# Out:
# Group String     Black  Low\nIncome       LEP  General\nPopulation  \
# period
# EM            0.883646     1.000000  0.971351             0.955585
# AM            0.915006     0.947969  0.954401             0.970680
# MD            0.941001     0.972697  0.950853             0.973555
# PM            0.933084     0.950591  0.952557             0.977808
# EV            0.934002     0.984561  0.957345             0.977102
#
# Group String  Carless\nHouseholds  Racialized  Recent\nImmigrants
# period
# EM                       0.948636    0.938036            0.967113
# AM                       0.979583    0.982869            1.000000
# MD                       0.989362    0.980846            1.000000
# PM                       0.990536    0.987911            1.000000
# EV                       0.996356    0.985569            1.000000

# %%
import seaborn as sns

fig, ax = plt.subplots()

fig.set_size_inches([6.5,3])

sns.heatmap(od_con_pivot_n, ax = ax, cmap = 'viridis_r', annot=True, fmt = '.2f', 
                vmin = od_con_pivot_n.min().min(), vmax = 1)

ax.tick_params(axis='y', rotation=0)
ax.tick_params(axis='x', rotation=0)

ax.set_ylabel('Period')
ax.set_ylabel('Group')
ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize = 7)
# Out:
# [Text(0.5, 0, 'Black'),
#  Text(1.5, 0, 'Low\nIncome'),
#  Text(2.5, 0, 'LEP'),
#  Text(3.5, 0, 'General\nPopulation'),
#  Text(4.5, 0, 'Carless\nHouseholds'),
#  Text(5.5, 0, 'Racialized'),
#  Text(6.5, 0, 'Recent\nImmigrants')]
